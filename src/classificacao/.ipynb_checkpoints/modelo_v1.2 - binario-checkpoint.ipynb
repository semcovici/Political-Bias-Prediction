# %%
# == importando bibliotecas == 

import pandas as pd
import numpy as np
from tqdm import tqdm
import string
import textblob
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection, metrics
from sklearn import preprocessing
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from tensorflow import keras
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras import models, optimizers
# from tensorflow.keras.layers import LSTM, Convolution1D, GRU, Dense, Dropout, Input, Embedding, SpatialDropout1D, Bidirectional
from tensorflow.keras.layers import *
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')

# %%
# # == download do modelo pré-treinado de word embedding == 

# inglês
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.vec.gz
# !gunzip cc.en.300.vec.gz
# !mv cc.en.300.vec ../../dataset/fasttext_word_embedding/en_word_embedding.vec

# português
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.pt.300.vec.gz
# !gunzip cc.pt.300.vec.gz
# !mv cc.pt.300.vec ../../fasttext_word_embedding/pt_word_embedding.vec

# %%
# == variáveis == 

path_pt = 'dados_treino_ingles'
path_en = 'dados_treino_pt_google_trad'
path = path_pt
word_embedding_en = 'en_word_embedding.vec'
word_embedding_pt = 'pt_word_embedding.vec'
word_embedding = word_embedding_pt

# %%
# == importar dados ==

df = pd.read_parquet(f'../../dataset/processed/artigos_de_partidos/artigos_partidos.parquet')

# %%
# == contagem de artigos por viés ==

df[df.Vies == 'direita'].Partido.value_counts() / df[df.Vies == 'direita'].shape[0]
df[df.Vies == 'esquerda'].Partido.value_counts() / df[df.Vies == 'esquerda'].shape[0]
df[df.Vies == 'centro'].Partido.value_counts() / df[df.Vies == 'centro'].shape[0]
# Out:
# 'direita'
# PL              0.620759
# Novo            0.219512
# PP              0.107647
# União Brasil    0.052081
# Name: Partido, dtype: float64
# PSTU     0.242835
# PCB      0.238962
# PCDoB    0.233153
# PT       0.231216
# Rede     0.048025
# PSOL     0.005809
# Name: Partido, dtype: float64
# PSB    0.479065
# PV     0.235998
# MDB    0.163404
# PDT    0.121533
# Name: Partido, dtype: float64

# %%
# == contagem de artigos por viés ==

df[df.Vies == 'direita'].Partido.value_counts() / df.shape[0]
df[df.Vies == 'esquerda'].Partido.value_counts() / df.shape[0]
df[df.Vies == 'centro'].Partido.value_counts() / df.shape[0]
# Out:
# PL              0.288995
# Novo            0.102194
# PP              0.050115
# União Brasil    0.024247
# Name: Partido, dtype: float64
# PSTU     0.053530
# PCB      0.052677
# PCDoB    0.051396
# PT       0.050969
# Rede     0.010587
# PSOL     0.001281
# Name: Partido, dtype: float64
# PSB    0.150431
# PV     0.074106
# MDB    0.051311
# PDT    0.038163
# Name: Partido, dtype: float64

# %%
# == separar aproximadamente 5% de cada viés para usar como validação ==

train = df[~df.Partido.isin(['PP', 'PT', 'MDB'])]
valid = df[df.Partido.isin(['PP', 'PT', 'MDB'])]

# %%
# == conjunto treino e teste == 

train[['Partido', 'Vies']].value_counts().to_frame()
valid[['Partido', 'Vies']].value_counts().to_frame()
# Out:
#                           0
# Partido      Vies
# PL           direita   3385
# PSB          centro    1762
# Novo         direita   1197
# PV           centro     868
# PSTU         esquerda   627
# PCB          esquerda   617
# PCDoB        esquerda   602
# PDT          centro     447
# União Brasil direita    284
# Rede         esquerda   124
# PSOL         esquerda    15
#                     0
# Partido Vies
# MDB     centro    601
# PT      esquerda  597
# PP      direita   587

# %%
# == train & test split ==

X_train, X_valid, y_train, y_valid = train.Conteudo, valid.Conteudo, train.Vies, valid.Vies

# %%
# == label encoding do rótulo == 

encoder = preprocessing.LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_valid = encoder.fit_transform(y_valid)

# %%
# == label das classes == 

encoder.classes_
encoder.inverse_transform([0,1,2])
# Out:
# array(['centro', 'direita', 'esquerda'], dtype=object)
# array(['centro', 'direita', 'esquerda'], dtype=object)

# %%
# == count vectorizer ==

count_vect = CountVectorizer(
    analyzer='word', 
    token_pattern=r'\w{1,}'
)
count_vect.fit(df.Conteudo)
X_train_count =  count_vect.transform(X_train)
X_valid_count =  count_vect.transform(X_valid)
# Out:
# CountVectorizer(token_pattern='\\w{1,}')

# %%
# == word level tf-idf ==

tfidf_vect = TfidfVectorizer(
    analyzer='word', 
    max_features=100
)
tfidf_vect.fit(df.Conteudo)
X_train_tfidf = tfidf_vect.transform(X_train)
X_valid_tfidf = tfidf_vect.transform(X_valid)
# Out:
# TfidfVectorizer(max_features=100)

# %%
# == ngram level tf-idf ==

tfidf_vect_ngram = TfidfVectorizer(
    analyzer='word', 
    ngram_range=(1,3), 
    max_features=100
)
tfidf_vect_ngram.fit(df.Conteudo)
X_train_tfidf_ngram =  tfidf_vect_ngram.transform(X_train)
X_valid_tfidf_ngram =  tfidf_vect_ngram.transform(X_valid)
# Out:
# TfidfVectorizer(max_features=100, ngram_range=(1, 3))

# %%
# == characters level tf-idf ==

tfidf_vect_ngram_chars = TfidfVectorizer(
    analyzer='char', 
    ngram_range=(1,3), 
    max_features=100
)
tfidf_vect_ngram_chars.fit(df.Conteudo)
X_train_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(X_train) 
X_valid_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(X_valid)
# Out:
# TfidfVectorizer(analyzer='char', max_features=100, ngram_range=(1, 3))

# %%
# == fazer load do vetor pré-treinado de word embedding ==  

embedding_idx = {}
for i, line in tqdm(enumerate(open(f'../../dataset/fasttext_word_embedding/{word_embedding}'))):
    values = line.split()
    embedding_idx[values[0]] = np.asarray(values[1:] , dtype='float32')
# Out:
# 2000001it [02:01, 16424.59it/s]

# %%
# == criar um tokenizador ==

token = text.Tokenizer()
token.fit_on_texts(df.Conteudo)
word_index = token.word_index

# %%
# == converter texto para sequência de tokens e preenchê-los para ter o mesmo tamanho == 

X_train_seq = sequence.pad_sequences(token.texts_to_sequences(X_train), maxlen=150)
X_valid_seq = sequence.pad_sequences(token.texts_to_sequences(X_valid), maxlen=150)

# %%
# == criar map de token-embedding ==

embedding_matrix = np.zeros((len(word_index) + 1, 300))
for word, i in word_index.items():
    embedding_vector = embedding_idx.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
encoder.inverse_transform([0,1,2])
# Out:
# array(['centro', 'direita', 'esquerda'], dtype=object)

# %%
# == método para trieinar o modelo == 

def train_model(model, X_train, y_train, X_valid, is_neural):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    
    print(y_pred)
    if is_neural: 
        y_pred = np.argmax(y_pred, axis=1)
        
    cr = pd.DataFrame(
        classification_report(
            y_pred, 
            y_valid, 
            digits=2,
            output_dict=True,
            target_names=encoder.inverse_transform([0,1,2])
        )
    ).T
    cr['support'] = cr.support.apply(int)
    
    cm = pd.DataFrame(
        confusion_matrix(
            y_valid,
            y_pred
        )
    )
    cm.columns = ['centro', 'direita', 'esquerda']
    cm.index = ['centro', 'direita', 'esquerda']
    
    return cr, cm

# %%
# == logistic regression == 

model = LogisticRegression(solver='liblinear')

print('Logistic Regression, Count Vectors:')
cr, cm = train_model(
    model, 
    X_train_count, 
    y_train, 
    X_valid_count, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Logistic Regression, WordLevel TF-IDF: ")
cr, cm = train_model(
    model, 
    X_train_tfidf, 
    y_train, 
    X_valid_tfidf, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Logistic Regression, N-Gram Vectors: ")
cr, cm = train_model(
    model, 
    X_train_tfidf_ngram, 
    y_train, 
    X_valid_tfidf_ngram, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Logistic Regression, CharLevel Vectors: ")
cr, cm = train_model(
    model, 
    X_train_tfidf_ngram_chars, 
    y_train, 
    X_valid_tfidf_ngram_chars, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# Logistic Regression, Count Vectors:
# <style type="text/css">
# #T_4fbd1_row0_col0, #T_4fbd1_row1_col1, #T_4fbd1_row2_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_4fbd1_row0_col1, #T_4fbd1_row0_col2, #T_4fbd1_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_4fbd1_row1_col2, #T_4fbd1_row2_col1 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_4fbd1_row2_col0 {
#   background-color: #75d054;
#   color: #000000;
# }
# </style>
# <table id="T_4fbd1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fbd1_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_4fbd1_row0_col0" class="data row0 col0" >595</td>
#       <td id="T_4fbd1_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_4fbd1_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4fbd1_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_4fbd1_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_4fbd1_row1_col1" class="data row1 col1" >578</td>
#       <td id="T_4fbd1_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4fbd1_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_4fbd1_row2_col0" class="data row2 col0" >473</td>
#       <td id="T_4fbd1_row2_col1" class="data row2 col1" >107</td>
#       <td id="T_4fbd1_row2_col2" class="data row2 col2" >17</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_37f8f_row0_col0, #T_37f8f_row1_col2, #T_37f8f_row2_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_37f8f_row0_col1, #T_37f8f_row2_col0, #T_37f8f_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_37f8f_row0_col2 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_37f8f_row1_col0 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_37f8f_row1_col1 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_37f8f_row3_col0 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_37f8f_row3_col1, #T_37f8f_row5_col1 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_37f8f_row3_col2 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_37f8f_row4_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_37f8f_row4_col1 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_37f8f_row4_col2 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_37f8f_row5_col0 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_37f8f_row5_col2 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# </style>
# <table id="T_37f8f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37f8f_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_37f8f_row0_col0" class="data row0 col0" >0.990017</td>
#       <td id="T_37f8f_row0_col1" class="data row0 col1" >0.554004</td>
#       <td id="T_37f8f_row0_col2" class="data row0 col2" >0.710448</td>
#       <td id="T_37f8f_row0_col3" class="data row0 col3" >1074</td>
#     </tr>
#     <tr>
#       <th id="T_37f8f_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_37f8f_row1_col0" class="data row1 col0" >0.984668</td>
#       <td id="T_37f8f_row1_col1" class="data row1 col1" >0.836469</td>
#       <td id="T_37f8f_row1_col2" class="data row1 col2" >0.904538</td>
#       <td id="T_37f8f_row1_col3" class="data row1 col3" >691</td>
#     </tr>
#     <tr>
#       <th id="T_37f8f_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_37f8f_row2_col0" class="data row2 col0" >0.028476</td>
#       <td id="T_37f8f_row2_col1" class="data row2 col1" >0.850000</td>
#       <td id="T_37f8f_row2_col2" class="data row2 col2" >0.055105</td>
#       <td id="T_37f8f_row2_col3" class="data row2 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_37f8f_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_37f8f_row3_col0" class="data row3 col0" >0.666667</td>
#       <td id="T_37f8f_row3_col1" class="data row3 col1" >0.666667</td>
#       <td id="T_37f8f_row3_col2" class="data row3 col2" >0.666667</td>
#       <td id="T_37f8f_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_37f8f_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_37f8f_row4_col0" class="data row4 col0" >0.667720</td>
#       <td id="T_37f8f_row4_col1" class="data row4 col1" >0.746824</td>
#       <td id="T_37f8f_row4_col2" class="data row4 col2" >0.556697</td>
#       <td id="T_37f8f_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_37f8f_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_37f8f_row5_col0" class="data row5 col0" >0.977172</td>
#       <td id="T_37f8f_row5_col1" class="data row5 col1" >0.666667</td>
#       <td id="T_37f8f_row5_col2" class="data row5 col2" >0.778240</td>
#       <td id="T_37f8f_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>
# Logistic Regression, WordLevel TF-IDF:
# <style type="text/css">
# #T_2dd1c_row0_col0, #T_2dd1c_row1_col1, #T_2dd1c_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2dd1c_row0_col1, #T_2dd1c_row0_col2, #T_2dd1c_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2dd1c_row2_col0 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_2dd1c_row2_col1 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_2dd1c_row2_col2 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2dd1c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dd1c_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_2dd1c_row0_col0" class="data row0 col0" >557</td>
#       <td id="T_2dd1c_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_2dd1c_row0_col2" class="data row0 col2" >32</td>
#     </tr>
#     <tr>
#       <th id="T_2dd1c_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_2dd1c_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_2dd1c_row1_col1" class="data row1 col1" >517</td>
#       <td id="T_2dd1c_row1_col2" class="data row1 col2" >42</td>
#     </tr>
#     <tr>
#       <th id="T_2dd1c_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_2dd1c_row2_col0" class="data row2 col0" >447</td>
#       <td id="T_2dd1c_row2_col1" class="data row2 col1" >114</td>
#       <td id="T_2dd1c_row2_col2" class="data row2 col2" >36</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2bd14_row0_col0, #T_2bd14_row1_col1, #T_2bd14_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2bd14_row0_col1 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_2bd14_row0_col2 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_2bd14_row1_col0 {
#   background-color: #dde318;
#   color: #000000;
# }
# #T_2bd14_row2_col0, #T_2bd14_row2_col1, #T_2bd14_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2bd14_row3_col0 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_2bd14_row3_col1, #T_2bd14_row5_col1 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_2bd14_row3_col2 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_2bd14_row4_col0 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_2bd14_row4_col1 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_2bd14_row4_col2 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_2bd14_row5_col0 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_2bd14_row5_col2 {
#   background-color: #84d44b;
#   color: #000000;
# }
# </style>
# <table id="T_2bd14_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bd14_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_2bd14_row0_col0" class="data row0 col0" >0.926789</td>
#       <td id="T_2bd14_row0_col1" class="data row0 col1" >0.539729</td>
#       <td id="T_2bd14_row0_col2" class="data row0 col2" >0.682180</td>
#       <td id="T_2bd14_row0_col3" class="data row0 col3" >1032</td>
#     </tr>
#     <tr>
#       <th id="T_2bd14_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_2bd14_row1_col0" class="data row1 col0" >0.880750</td>
#       <td id="T_2bd14_row1_col1" class="data row1 col1" >0.804044</td>
#       <td id="T_2bd14_row1_col2" class="data row1 col2" >0.840650</td>
#       <td id="T_2bd14_row1_col3" class="data row1 col3" >643</td>
#     </tr>
#     <tr>
#       <th id="T_2bd14_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_2bd14_row2_col0" class="data row2 col0" >0.060302</td>
#       <td id="T_2bd14_row2_col1" class="data row2 col1" >0.327273</td>
#       <td id="T_2bd14_row2_col2" class="data row2 col2" >0.101839</td>
#       <td id="T_2bd14_row2_col3" class="data row2 col3" >110</td>
#     </tr>
#     <tr>
#       <th id="T_2bd14_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_2bd14_row3_col0" class="data row3 col0" >0.621849</td>
#       <td id="T_2bd14_row3_col1" class="data row3 col1" >0.621849</td>
#       <td id="T_2bd14_row3_col2" class="data row3 col2" >0.621849</td>
#       <td id="T_2bd14_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2bd14_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_2bd14_row4_col0" class="data row4 col0" >0.622613</td>
#       <td id="T_2bd14_row4_col1" class="data row4 col1" >0.557015</td>
#       <td id="T_2bd14_row4_col2" class="data row4 col2" >0.541556</td>
#       <td id="T_2bd14_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_2bd14_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_2bd14_row5_col0" class="data row5 col0" >0.856807</td>
#       <td id="T_2bd14_row5_col1" class="data row5 col1" >0.621849</td>
#       <td id="T_2bd14_row5_col2" class="data row5 col2" >0.703502</td>
#       <td id="T_2bd14_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>
# Logistic Regression, N-Gram Vectors:
# <style type="text/css">
# #T_46048_row0_col0, #T_46048_row1_col1, #T_46048_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_46048_row0_col1, #T_46048_row0_col2, #T_46048_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_46048_row2_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_46048_row2_col1 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_46048_row2_col2 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_46048_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46048_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_46048_row0_col0" class="data row0 col0" >556</td>
#       <td id="T_46048_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_46048_row0_col2" class="data row0 col2" >33</td>
#     </tr>
#     <tr>
#       <th id="T_46048_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_46048_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_46048_row1_col1" class="data row1 col1" >518</td>
#       <td id="T_46048_row1_col2" class="data row1 col2" >41</td>
#     </tr>
#     <tr>
#       <th id="T_46048_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_46048_row2_col0" class="data row2 col0" >451</td>
#       <td id="T_46048_row2_col1" class="data row2 col1" >112</td>
#       <td id="T_46048_row2_col2" class="data row2 col2" >34</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_92a93_row0_col0, #T_92a93_row1_col1, #T_92a93_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_92a93_row0_col1 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_92a93_row0_col2 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_92a93_row1_col0 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_92a93_row2_col0, #T_92a93_row2_col1, #T_92a93_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_92a93_row3_col0, #T_92a93_row4_col0 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_92a93_row3_col1, #T_92a93_row5_col1 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_92a93_row3_col2 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_92a93_row4_col1 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_92a93_row4_col2 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_92a93_row5_col0 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_92a93_row5_col2 {
#   background-color: #84d44b;
#   color: #000000;
# }
# </style>
# <table id="T_92a93_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92a93_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_92a93_row0_col0" class="data row0 col0" >0.925125</td>
#       <td id="T_92a93_row0_col1" class="data row0 col1" >0.537198</td>
#       <td id="T_92a93_row0_col2" class="data row0 col2" >0.679707</td>
#       <td id="T_92a93_row0_col3" class="data row0 col3" >1035</td>
#     </tr>
#     <tr>
#       <th id="T_92a93_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_92a93_row1_col0" class="data row1 col0" >0.882453</td>
#       <td id="T_92a93_row1_col1" class="data row1 col1" >0.806854</td>
#       <td id="T_92a93_row1_col2" class="data row1 col2" >0.842962</td>
#       <td id="T_92a93_row1_col3" class="data row1 col3" >642</td>
#     </tr>
#     <tr>
#       <th id="T_92a93_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_92a93_row2_col0" class="data row2 col0" >0.056951</td>
#       <td id="T_92a93_row2_col1" class="data row2 col1" >0.314815</td>
#       <td id="T_92a93_row2_col2" class="data row2 col2" >0.096454</td>
#       <td id="T_92a93_row2_col3" class="data row2 col3" >108</td>
#     </tr>
#     <tr>
#       <th id="T_92a93_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_92a93_row3_col0" class="data row3 col0" >0.620728</td>
#       <td id="T_92a93_row3_col1" class="data row3 col1" >0.620728</td>
#       <td id="T_92a93_row3_col2" class="data row3 col2" >0.620728</td>
#       <td id="T_92a93_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_92a93_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_92a93_row4_col0" class="data row4 col0" >0.621510</td>
#       <td id="T_92a93_row4_col1" class="data row4 col1" >0.552955</td>
#       <td id="T_92a93_row4_col2" class="data row4 col2" >0.539707</td>
#       <td id="T_92a93_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_92a93_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_92a93_row5_col0" class="data row5 col0" >0.857249</td>
#       <td id="T_92a93_row5_col1" class="data row5 col1" >0.620728</td>
#       <td id="T_92a93_row5_col2" class="data row5 col2" >0.703134</td>
#       <td id="T_92a93_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>
# Logistic Regression, CharLevel Vectors:
# <style type="text/css">
# #T_e83b0_row0_col0 {
#   background-color: #eae51a;
#   color: #000000;
# }
# #T_e83b0_row0_col1 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_e83b0_row0_col2 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_e83b0_row1_col0, #T_e83b0_row1_col2, #T_e83b0_row2_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_e83b0_row1_col1, #T_e83b0_row2_col0, #T_e83b0_row2_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_e83b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e83b0_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_e83b0_row0_col0" class="data row0 col0" >540</td>
#       <td id="T_e83b0_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_e83b0_row0_col2" class="data row0 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_e83b0_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_e83b0_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_e83b0_row1_col1" class="data row1 col1" >578</td>
#       <td id="T_e83b0_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e83b0_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_e83b0_row2_col0" class="data row2 col0" >559</td>
#       <td id="T_e83b0_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_e83b0_row2_col2" class="data row2 col2" >36</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d4da1_row0_col0, #T_d4da1_row5_col0 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_d4da1_row0_col1, #T_d4da1_row2_col0, #T_d4da1_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_d4da1_row0_col2 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_d4da1_row1_col0, #T_d4da1_row1_col1, #T_d4da1_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d4da1_row2_col1 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_d4da1_row3_col0, #T_d4da1_row3_col2, #T_d4da1_row4_col0 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_d4da1_row3_col1, #T_d4da1_row5_col1 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_d4da1_row4_col1 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_d4da1_row4_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_d4da1_row5_col2 {
#   background-color: #54c568;
#   color: #000000;
# }
# </style>
# <table id="T_d4da1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4da1_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_d4da1_row0_col0" class="data row0 col0" >0.898502</td>
#       <td id="T_d4da1_row0_col1" class="data row0 col1" >0.488688</td>
#       <td id="T_d4da1_row0_col2" class="data row0 col2" >0.633060</td>
#       <td id="T_d4da1_row0_col3" class="data row0 col3" >1105</td>
#     </tr>
#     <tr>
#       <th id="T_d4da1_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_d4da1_row1_col0" class="data row1 col0" >0.984668</td>
#       <td id="T_d4da1_row1_col1" class="data row1 col1" >0.929260</td>
#       <td id="T_d4da1_row1_col2" class="data row1 col2" >0.956162</td>
#       <td id="T_d4da1_row1_col3" class="data row1 col3" >622</td>
#     </tr>
#     <tr>
#       <th id="T_d4da1_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_d4da1_row2_col0" class="data row2 col0" >0.060302</td>
#       <td id="T_d4da1_row2_col1" class="data row2 col1" >0.620690</td>
#       <td id="T_d4da1_row2_col2" class="data row2 col2" >0.109924</td>
#       <td id="T_d4da1_row2_col3" class="data row2 col3" >58</td>
#     </tr>
#     <tr>
#       <th id="T_d4da1_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_d4da1_row3_col0" class="data row3 col0" >0.646499</td>
#       <td id="T_d4da1_row3_col1" class="data row3 col1" >0.646499</td>
#       <td id="T_d4da1_row3_col2" class="data row3 col2" >0.646499</td>
#       <td id="T_d4da1_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4da1_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_d4da1_row4_col0" class="data row4 col0" >0.647824</td>
#       <td id="T_d4da1_row4_col1" class="data row4 col1" >0.679546</td>
#       <td id="T_d4da1_row4_col2" class="data row4 col2" >0.566382</td>
#       <td id="T_d4da1_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_d4da1_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_d4da1_row5_col0" class="data row5 col0" >0.901292</td>
#       <td id="T_d4da1_row5_col1" class="data row5 col1" >0.646499</td>
#       <td id="T_d4da1_row5_col2" class="data row5 col2" >0.728650</td>
#       <td id="T_d4da1_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == support vector machine (svm)

print ("Suport Vector Machine, N-Gram Vectors: ")
cr, cm = train_model(
    SVC(), 
    X_train_tfidf_ngram, 
    y_train, 
    X_valid_tfidf_ngram,
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# Suport Vector Machine, N-Gram Vectors:
# <style type="text/css">
# #T_1aade_row0_col0, #T_1aade_row1_col1, #T_1aade_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_1aade_row0_col1, #T_1aade_row0_col2, #T_1aade_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1aade_row2_col0 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_1aade_row2_col1 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_1aade_row2_col2 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1aade_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1aade_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_1aade_row0_col0" class="data row0 col0" >600</td>
#       <td id="T_1aade_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1aade_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1aade_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_1aade_row1_col0" class="data row1 col0" >42</td>
#       <td id="T_1aade_row1_col1" class="data row1 col1" >525</td>
#       <td id="T_1aade_row1_col2" class="data row1 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_1aade_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_1aade_row2_col0" class="data row2 col0" >430</td>
#       <td id="T_1aade_row2_col1" class="data row2 col1" >156</td>
#       <td id="T_1aade_row2_col2" class="data row2 col2" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_91b61_row0_col0, #T_91b61_row1_col1, #T_91b61_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_91b61_row0_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_91b61_row0_col2 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_91b61_row1_col0 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_91b61_row2_col0, #T_91b61_row2_col1, #T_91b61_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_91b61_row3_col0, #T_91b61_row4_col0 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_91b61_row3_col1, #T_91b61_row5_col1 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_91b61_row3_col2 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_91b61_row4_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_91b61_row4_col2 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_91b61_row5_col0 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_91b61_row5_col2 {
#   background-color: #bade28;
#   color: #000000;
# }
# </style>
# <table id="T_91b61_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91b61_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_91b61_row0_col0" class="data row0 col0" >0.998336</td>
#       <td id="T_91b61_row0_col1" class="data row0 col1" >0.559701</td>
#       <td id="T_91b61_row0_col2" class="data row0 col2" >0.717274</td>
#       <td id="T_91b61_row0_col3" class="data row0 col3" >1072</td>
#     </tr>
#     <tr>
#       <th id="T_91b61_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_91b61_row1_col0" class="data row1 col0" >0.894378</td>
#       <td id="T_91b61_row1_col1" class="data row1 col1" >0.770925</td>
#       <td id="T_91b61_row1_col2" class="data row1 col2" >0.828076</td>
#       <td id="T_91b61_row1_col3" class="data row1 col3" >681</td>
#     </tr>
#     <tr>
#       <th id="T_91b61_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_91b61_row2_col0" class="data row2 col0" >0.018425</td>
#       <td id="T_91b61_row2_col1" class="data row2 col1" >0.343750</td>
#       <td id="T_91b61_row2_col2" class="data row2 col2" >0.034976</td>
#       <td id="T_91b61_row2_col3" class="data row2 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_91b61_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_91b61_row3_col0" class="data row3 col0" >0.636415</td>
#       <td id="T_91b61_row3_col1" class="data row3 col1" >0.636415</td>
#       <td id="T_91b61_row3_col2" class="data row3 col2" >0.636415</td>
#       <td id="T_91b61_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_91b61_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_91b61_row4_col0" class="data row4 col0" >0.637047</td>
#       <td id="T_91b61_row4_col1" class="data row4 col1" >0.558126</td>
#       <td id="T_91b61_row4_col2" class="data row4 col2" >0.526775</td>
#       <td id="T_91b61_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_91b61_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_91b61_row5_col0" class="data row5 col0" >0.941108</td>
#       <td id="T_91b61_row5_col1" class="data row5 col1" >0.636415</td>
#       <td id="T_91b61_row5_col2" class="data row5 col2" >0.747315</td>
#       <td id="T_91b61_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == random forest classifier == 

print ("Random Forest, Count Vectors: ")
cr, cm = train_model(
    RandomForestClassifier(
        n_estimators=500
    ), 
    X_train_count, 
    y_train, 
    X_valid_count,
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Random Forest, WordLevel TF-IDF: ")
cr, cm = train_model(
    RandomForestClassifier(
        n_estimators=500
    ), 
    X_train_tfidf, 
    y_train, 
    X_valid_tfidf,
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# Random Forest, Count Vectors:
# <style type="text/css">
# #T_046c4_row0_col0, #T_046c4_row1_col1, #T_046c4_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_046c4_row0_col1, #T_046c4_row1_col0, #T_046c4_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_046c4_row0_col2 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_046c4_row2_col0 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_046c4_row2_col1 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_046c4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_046c4_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_046c4_row0_col0" class="data row0 col0" >598</td>
#       <td id="T_046c4_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_046c4_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_046c4_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_046c4_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_046c4_row1_col1" class="data row1 col1" >584</td>
#       <td id="T_046c4_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_046c4_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_046c4_row2_col0" class="data row2 col0" >563</td>
#       <td id="T_046c4_row2_col1" class="data row2 col1" >34</td>
#       <td id="T_046c4_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1f97b_row0_col0, #T_1f97b_row1_col0, #T_1f97b_row1_col1, #T_1f97b_row1_col2, #T_1f97b_row5_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_1f97b_row0_col1 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_1f97b_row0_col2, #T_1f97b_row3_col1, #T_1f97b_row5_col1 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_1f97b_row2_col0, #T_1f97b_row2_col1, #T_1f97b_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1f97b_row3_col0, #T_1f97b_row4_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_1f97b_row3_col2 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_1f97b_row4_col1 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_1f97b_row4_col2 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_1f97b_row5_col2 {
#   background-color: #7cd250;
#   color: #000000;
# }
# </style>
# <table id="T_1f97b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f97b_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_1f97b_row0_col0" class="data row0 col0" >0.995008</td>
#       <td id="T_1f97b_row0_col1" class="data row0 col1" >0.515073</td>
#       <td id="T_1f97b_row0_col2" class="data row0 col2" >0.678774</td>
#       <td id="T_1f97b_row0_col3" class="data row0 col3" >1161</td>
#     </tr>
#     <tr>
#       <th id="T_1f97b_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_1f97b_row1_col0" class="data row1 col0" >0.994889</td>
#       <td id="T_1f97b_row1_col1" class="data row1 col1" >0.941935</td>
#       <td id="T_1f97b_row1_col2" class="data row1 col2" >0.967688</td>
#       <td id="T_1f97b_row1_col3" class="data row1 col3" >620</td>
#     </tr>
#     <tr>
#       <th id="T_1f97b_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_1f97b_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_1f97b_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_1f97b_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_1f97b_row2_col3" class="data row2 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1f97b_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_1f97b_row3_col0" class="data row3 col0" >0.662185</td>
#       <td id="T_1f97b_row3_col1" class="data row3 col1" >0.662185</td>
#       <td id="T_1f97b_row3_col2" class="data row3 col2" >0.662185</td>
#       <td id="T_1f97b_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1f97b_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_1f97b_row4_col0" class="data row4 col0" >0.663299</td>
#       <td id="T_1f97b_row4_col1" class="data row4 col1" >0.485670</td>
#       <td id="T_1f97b_row4_col2" class="data row4 col2" >0.548821</td>
#       <td id="T_1f97b_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_1f97b_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_1f97b_row5_col0" class="data row5 col0" >0.992737</td>
#       <td id="T_1f97b_row5_col1" class="data row5 col1" >0.662185</td>
#       <td id="T_1f97b_row5_col2" class="data row5 col2" >0.777604</td>
#       <td id="T_1f97b_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>
# Random Forest, WordLevel TF-IDF:
# <style type="text/css">
# #T_9765a_row0_col0, #T_9765a_row1_col1, #T_9765a_row2_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9765a_row0_col1, #T_9765a_row0_col2, #T_9765a_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_9765a_row1_col2 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_9765a_row2_col0 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_9765a_row2_col1 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9765a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9765a_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_9765a_row0_col0" class="data row0 col0" >598</td>
#       <td id="T_9765a_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_9765a_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9765a_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_9765a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9765a_row1_col1" class="data row1 col1" >580</td>
#       <td id="T_9765a_row1_col2" class="data row1 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9765a_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_9765a_row2_col0" class="data row2 col0" >184</td>
#       <td id="T_9765a_row2_col1" class="data row2 col1" >405</td>
#       <td id="T_9765a_row2_col2" class="data row2 col2" >8</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_11e3a_row0_col0, #T_11e3a_row0_col1, #T_11e3a_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_11e3a_row1_col0 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_11e3a_row1_col1, #T_11e3a_row2_col0, #T_11e3a_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_11e3a_row1_col2 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_11e3a_row2_col1 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_11e3a_row3_col0 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_11e3a_row3_col1, #T_11e3a_row5_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_11e3a_row3_col2 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_11e3a_row4_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_11e3a_row4_col1 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_11e3a_row4_col2 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_11e3a_row5_col0 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_11e3a_row5_col2 {
#   background-color: #c2df23;
#   color: #000000;
# }
# </style>
# <table id="T_11e3a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11e3a_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_11e3a_row0_col0" class="data row0 col0" >0.995008</td>
#       <td id="T_11e3a_row0_col1" class="data row0 col1" >0.762755</td>
#       <td id="T_11e3a_row0_col2" class="data row0 col2" >0.863538</td>
#       <td id="T_11e3a_row0_col3" class="data row0 col3" >784</td>
#     </tr>
#     <tr>
#       <th id="T_11e3a_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_11e3a_row1_col0" class="data row1 col0" >0.988075</td>
#       <td id="T_11e3a_row1_col1" class="data row1 col1" >0.587045</td>
#       <td id="T_11e3a_row1_col2" class="data row1 col2" >0.736508</td>
#       <td id="T_11e3a_row1_col3" class="data row1 col3" >988</td>
#     </tr>
#     <tr>
#       <th id="T_11e3a_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_11e3a_row2_col0" class="data row2 col0" >0.013400</td>
#       <td id="T_11e3a_row2_col1" class="data row2 col1" >0.615385</td>
#       <td id="T_11e3a_row2_col2" class="data row2 col2" >0.026230</td>
#       <td id="T_11e3a_row2_col3" class="data row2 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_11e3a_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_11e3a_row3_col0" class="data row3 col0" >0.664426</td>
#       <td id="T_11e3a_row3_col1" class="data row3 col1" >0.664426</td>
#       <td id="T_11e3a_row3_col2" class="data row3 col2" >0.664426</td>
#       <td id="T_11e3a_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_11e3a_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_11e3a_row4_col0" class="data row4 col0" >0.665495</td>
#       <td id="T_11e3a_row4_col1" class="data row4 col1" >0.655061</td>
#       <td id="T_11e3a_row4_col2" class="data row4 col2" >0.542092</td>
#       <td id="T_11e3a_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_11e3a_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_11e3a_row5_col0" class="data row5 col0" >0.984022</td>
#       <td id="T_11e3a_row5_col1" class="data row5 col1" >0.664426</td>
#       <td id="T_11e3a_row5_col2" class="data row5 col2" >0.787129</td>
#       <td id="T_11e3a_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == gradient boost == 

model = XGBClassifier(
    use_label_encoder=False, 
    eval_metric='mlogloss',
    learning_rate=0.01,
    n_estimators=500
)

print ("XGBClassifier, Count Vectors: ")
cr, cm = train_model(
    model, 
    X_train_count.tocsc(), 
    y_train, 
    X_valid_count.tocsc(), 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("XGBClassifier, WordLevel TF-IDF: ")
cr, cm = train_model(
    model, 
    X_train_tfidf.tocsc(), 
    y_train, 
    X_valid_tfidf.tocsc(), 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("XGBClassifier, CharLevel Vectors: ")
cr, cm = train_model(
    model, 
    X_train_tfidf_ngram_chars.tocsc(), 
    y_train, 
    X_valid_tfidf_ngram_chars.tocsc(), 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# XGBClassifier, Count Vectors:
# <style type="text/css">
# #T_bedf3_row0_col0, #T_bedf3_row0_col2, #T_bedf3_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_bedf3_row0_col1, #T_bedf3_row1_col0, #T_bedf3_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_bedf3_row2_col0 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_bedf3_row2_col1 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_bedf3_row2_col2 {
#   background-color: #5ec962;
#   color: #000000;
# }
# </style>
# <table id="T_bedf3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bedf3_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_bedf3_row0_col0" class="data row0 col0" >402</td>
#       <td id="T_bedf3_row0_col1" class="data row0 col1" >68</td>
#       <td id="T_bedf3_row0_col2" class="data row0 col2" >131</td>
#     </tr>
#     <tr>
#       <th id="T_bedf3_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_bedf3_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_bedf3_row1_col1" class="data row1 col1" >560</td>
#       <td id="T_bedf3_row1_col2" class="data row1 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_bedf3_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_bedf3_row2_col0" class="data row2 col0" >79</td>
#       <td id="T_bedf3_row2_col1" class="data row2 col1" >418</td>
#       <td id="T_bedf3_row2_col2" class="data row2 col2" >100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_71caf_row0_col0, #T_71caf_row4_col2 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_71caf_row0_col1, #T_71caf_row0_col2, #T_71caf_row1_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_71caf_row1_col1 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_71caf_row1_col2 {
#   background-color: #c5e021;
#   color: #000000;
# }
# #T_71caf_row2_col0, #T_71caf_row2_col1, #T_71caf_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_71caf_row3_col0, #T_71caf_row4_col0 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_71caf_row3_col1, #T_71caf_row5_col1 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_71caf_row3_col2 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_71caf_row4_col1 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_71caf_row5_col0 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_71caf_row5_col2 {
#   background-color: #84d44b;
#   color: #000000;
# }
# </style>
# <table id="T_71caf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71caf_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_71caf_row0_col0" class="data row0 col0" >0.668885</td>
#       <td id="T_71caf_row0_col1" class="data row0 col1" >0.802395</td>
#       <td id="T_71caf_row0_col2" class="data row0 col2" >0.729583</td>
#       <td id="T_71caf_row0_col3" class="data row0 col3" >501</td>
#     </tr>
#     <tr>
#       <th id="T_71caf_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_71caf_row1_col0" class="data row1 col0" >0.954003</td>
#       <td id="T_71caf_row1_col1" class="data row1 col1" >0.535373</td>
#       <td id="T_71caf_row1_col2" class="data row1 col2" >0.685854</td>
#       <td id="T_71caf_row1_col3" class="data row1 col3" >1046</td>
#     </tr>
#     <tr>
#       <th id="T_71caf_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_71caf_row2_col0" class="data row2 col0" >0.167504</td>
#       <td id="T_71caf_row2_col1" class="data row2 col1" >0.420168</td>
#       <td id="T_71caf_row2_col2" class="data row2 col2" >0.239521</td>
#       <td id="T_71caf_row2_col3" class="data row2 col3" >238</td>
#     </tr>
#     <tr>
#       <th id="T_71caf_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_71caf_row3_col0" class="data row3 col0" >0.594958</td>
#       <td id="T_71caf_row3_col1" class="data row3 col1" >0.594958</td>
#       <td id="T_71caf_row3_col2" class="data row3 col2" >0.594958</td>
#       <td id="T_71caf_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_71caf_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_71caf_row4_col0" class="data row4 col0" >0.596798</td>
#       <td id="T_71caf_row4_col1" class="data row4 col1" >0.585979</td>
#       <td id="T_71caf_row4_col2" class="data row4 col2" >0.551653</td>
#       <td id="T_71caf_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_71caf_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_71caf_row5_col0" class="data row5 col0" >0.769112</td>
#       <td id="T_71caf_row5_col1" class="data row5 col1" >0.594958</td>
#       <td id="T_71caf_row5_col2" class="data row5 col2" >0.638616</td>
#       <td id="T_71caf_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>
# XGBClassifier, WordLevel TF-IDF:
# <style type="text/css">
# #T_e53cb_row0_col0, #T_e53cb_row1_col1, #T_e53cb_row2_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e53cb_row0_col1, #T_e53cb_row0_col2, #T_e53cb_row2_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_e53cb_row1_col0 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_e53cb_row1_col2 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_e53cb_row2_col1 {
#   background-color: #eae51a;
#   color: #000000;
# }
# </style>
# <table id="T_e53cb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e53cb_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_e53cb_row0_col0" class="data row0 col0" >579</td>
#       <td id="T_e53cb_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_e53cb_row0_col2" class="data row0 col2" >21</td>
#     </tr>
#     <tr>
#       <th id="T_e53cb_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_e53cb_row1_col0" class="data row1 col0" >83</td>
#       <td id="T_e53cb_row1_col1" class="data row1 col1" >473</td>
#       <td id="T_e53cb_row1_col2" class="data row1 col2" >31</td>
#     </tr>
#     <tr>
#       <th id="T_e53cb_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_e53cb_row2_col0" class="data row2 col0" >43</td>
#       <td id="T_e53cb_row2_col1" class="data row2 col1" >458</td>
#       <td id="T_e53cb_row2_col2" class="data row2 col2" >96</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_286f7_row0_col0, #T_286f7_row0_col1, #T_286f7_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_286f7_row1_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_286f7_row1_col1, #T_286f7_row2_col0, #T_286f7_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_286f7_row1_col2 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_286f7_row2_col1 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_286f7_row3_col0, #T_286f7_row4_col0 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_286f7_row3_col1, #T_286f7_row5_col1 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_286f7_row3_col2 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_286f7_row4_col1 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_286f7_row4_col2 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_286f7_row5_col0 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_286f7_row5_col2 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_286f7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_286f7_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_286f7_row0_col0" class="data row0 col0" >0.963394</td>
#       <td id="T_286f7_row0_col1" class="data row0 col1" >0.821277</td>
#       <td id="T_286f7_row0_col2" class="data row0 col2" >0.886677</td>
#       <td id="T_286f7_row0_col3" class="data row0 col3" >705</td>
#     </tr>
#     <tr>
#       <th id="T_286f7_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_286f7_row1_col0" class="data row1 col0" >0.805792</td>
#       <td id="T_286f7_row1_col1" class="data row1 col1" >0.507511</td>
#       <td id="T_286f7_row1_col2" class="data row1 col2" >0.622778</td>
#       <td id="T_286f7_row1_col3" class="data row1 col3" >932</td>
#     </tr>
#     <tr>
#       <th id="T_286f7_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_286f7_row2_col0" class="data row2 col0" >0.160804</td>
#       <td id="T_286f7_row2_col1" class="data row2 col1" >0.648649</td>
#       <td id="T_286f7_row2_col2" class="data row2 col2" >0.257718</td>
#       <td id="T_286f7_row2_col3" class="data row2 col3" >148</td>
#     </tr>
#     <tr>
#       <th id="T_286f7_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_286f7_row3_col0" class="data row3 col0" >0.643137</td>
#       <td id="T_286f7_row3_col1" class="data row3 col1" >0.643137</td>
#       <td id="T_286f7_row3_col2" class="data row3 col2" >0.643137</td>
#       <td id="T_286f7_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_286f7_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_286f7_row4_col0" class="data row4 col0" >0.643330</td>
#       <td id="T_286f7_row4_col1" class="data row4 col1" >0.659145</td>
#       <td id="T_286f7_row4_col2" class="data row4 col2" >0.589058</td>
#       <td id="T_286f7_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_286f7_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_286f7_row5_col0" class="data row5 col0" >0.814560</td>
#       <td id="T_286f7_row5_col1" class="data row5 col1" >0.643137</td>
#       <td id="T_286f7_row5_col2" class="data row5 col2" >0.696739</td>
#       <td id="T_286f7_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>
# XGBClassifier, CharLevel Vectors:
# <style type="text/css">
# #T_13f07_row0_col0 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_13f07_row0_col1 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_13f07_row0_col2, #T_13f07_row1_col1, #T_13f07_row2_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_13f07_row1_col0, #T_13f07_row2_col1, #T_13f07_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_13f07_row1_col2 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13f07_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13f07_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_13f07_row0_col0" class="data row0 col0" >573</td>
#       <td id="T_13f07_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_13f07_row0_col2" class="data row0 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_13f07_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_13f07_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_13f07_row1_col1" class="data row1 col1" >575</td>
#       <td id="T_13f07_row1_col2" class="data row1 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_13f07_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_13f07_row2_col0" class="data row2 col0" >582</td>
#       <td id="T_13f07_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_13f07_row2_col2" class="data row2 col2" >7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_53280_row0_col0 {
#   background-color: #efe51c;
#   color: #000000;
# }
# #T_53280_row0_col1 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_53280_row0_col2 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_53280_row1_col0, #T_53280_row1_col1, #T_53280_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_53280_row2_col0, #T_53280_row2_col1, #T_53280_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_53280_row3_col0, #T_53280_row4_col0 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_53280_row3_col1, #T_53280_row5_col1 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_53280_row3_col2 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_53280_row4_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_53280_row4_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_53280_row5_col0 {
#   background-color: #eae51a;
#   color: #000000;
# }
# #T_53280_row5_col2 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# </style>
# <table id="T_53280_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53280_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_53280_row0_col0" class="data row0 col0" >0.953411</td>
#       <td id="T_53280_row0_col1" class="data row0 col1" >0.494819</td>
#       <td id="T_53280_row0_col2" class="data row0 col2" >0.651507</td>
#       <td id="T_53280_row0_col3" class="data row0 col3" >1158</td>
#     </tr>
#     <tr>
#       <th id="T_53280_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_53280_row1_col0" class="data row1 col0" >0.979557</td>
#       <td id="T_53280_row1_col1" class="data row1 col1" >0.956739</td>
#       <td id="T_53280_row1_col2" class="data row1 col2" >0.968013</td>
#       <td id="T_53280_row1_col3" class="data row1 col3" >601</td>
#     </tr>
#     <tr>
#       <th id="T_53280_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_53280_row2_col0" class="data row2 col0" >0.011725</td>
#       <td id="T_53280_row2_col1" class="data row2 col1" >0.269231</td>
#       <td id="T_53280_row2_col2" class="data row2 col2" >0.022472</td>
#       <td id="T_53280_row2_col3" class="data row2 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_53280_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_53280_row3_col0" class="data row3 col0" >0.647059</td>
#       <td id="T_53280_row3_col1" class="data row3 col1" >0.647059</td>
#       <td id="T_53280_row3_col2" class="data row3 col2" >0.647059</td>
#       <td id="T_53280_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_53280_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_53280_row4_col0" class="data row4 col0" >0.648231</td>
#       <td id="T_53280_row4_col1" class="data row4 col1" >0.573596</td>
#       <td id="T_53280_row4_col2" class="data row4 col2" >0.547331</td>
#       <td id="T_53280_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_53280_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_53280_row5_col0" class="data row5 col0" >0.948498</td>
#       <td id="T_53280_row5_col1" class="data row5 col1" >0.647059</td>
#       <td id="T_53280_row5_col2" class="data row5 col2" >0.748910</td>
#       <td id="T_53280_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == arquitetura lstm == 

def lstm():
    # limpar a sessão
    keras.backend.clear_session()
    # iniciar o modelo 
    model = keras.Sequential()
    # camada de entrada
    model.add(Input((150, )))
    # camada de word embedding
    model.add(Embedding(
        len(word_index) + 1, 
        300, 
        weights=[embedding_matrix], 
        trainable=True
    ))
    model.add(Convolution1D(
        128, 
        3, 
        activation="relu"
    ))
    model.add(GlobalMaxPool1D())
    # model.add(SpatialDropout1D(0.2))
    # camada LSTM
    model.add(Dropout(0.2))
    model.add(LSTM(128, return_sequences=True, activation='relu'))
    model.add(Dropout(0.2))
    model.add(LSTM(128))
    model.add(Dropout(0.2))
    # camadas de saída
    model.add(Dense(1, activation="sigmoid"))
    # compilar o modelo
    model.compile(optimizer=optimizers.Adam(), metrics='accuracy', loss='binary_crossentropy')
    model.summary()
    return model

print ("RNN-LSTM, Word Embeddings")
cr, cm = train_model(
    lstm(), 
    X_train_seq, 
    y_train, 
    X_valid_seq, 
    True
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# RNN-LSTM, Word Embeddings
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# <ipython-input-89-48551962afb0> in <module>
#      37 print ("RNN-LSTM, Word Embeddings")
#      38 cr, cm = train_model(
# ---> 39     lstm(),
#      40     X_train_seq,
#      41     y_train,
#
# <ipython-input-89-48551962afb0> in lstm()
#      24     # camada LSTM
#      25     model.add(Dropout(0.2))
# ---> 26     model.add(LSTM(128, return_sequences=True, activation='relu'))
#      27     model.add(Dropout(0.2))
#      28     model.add(LSTM(128))
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     203     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204     try:
# --> 205       result = method(self, *args, **kwargs)
#     206     finally:
#     207       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     231             if ndim != spec.ndim:
#     232                 raise ValueError(
# --> 233                     f'Input {input_index} of layer "{layer_name}" '
#     234                     "is incompatible with the layer: "
#     235                     f"expected ndim={spec.ndim}, found ndim={ndim}. "
#
# ValueError: Input 0 of layer "lstm" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 128)

# %%
# == arquitetura recurrent convolutional neural network (RCNN) == 

def rcnn():
    # limpar a sessão
    keras.backend.clear_session()
    # iniciar o modelo 
    model = keras.Sequential()
    # camada de entrada 
    model.add(Input((150, )))
    # camada de word embedding 
    model.add(Embedding(
        len(word_index) + 1, 
        300, 
        weights=[embedding_matrix], 
        trainable=True
    ))
    model.add(SpatialDropout1D(0.3))
    # camada recurrent 
    model.add(Bidirectional(
        GRU(
            50, 
            return_sequences=True
        )
    ))
    # camada convolucional
    model.add(Convolution1D(
        100, 
        3, 
        activation="relu"
    ))
    # camada pooling 
    model.add(GlobalMaxPool1D())
    # camada denso 
    model.add(Dense(
        50, 
        activation="relu"
    ))
    model.add(Dropout(0.25))
    model.add(Dense(
        1, 
        activation="sigmoid"
    ))
    # model compile
    model.compile(
        optimizer=optimizers.Adam(), 
        loss='binary_crossentropy'
    )
    model.summary()
    return model

print ("CNN, Word Embeddings")
cr, cm = train_model(
    rcnn(), 
    X_train_seq, 
    y_train, 
    X_valid_seq, 
    True
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# CNN, Word Embeddings
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 300)          33610800
#
#  spatial_dropout1d (SpatialD  (None, 150, 300)         0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 150, 100)         105600
#  l)
#
#  conv1d (Conv1D)             (None, 148, 100)          30100
#
#  global_max_pooling1d (Globa  (None, 100)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 50)                5050
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 33,751,601
# Trainable params: 33,751,601
# Non-trainable params: 0
# _________________________________________________________________
# 311/311 [==============================] - 118s 370ms/step - loss: -1830.1638
# 56/56 [==============================] - 2s 20ms/step
# [[0.43672243]
#  [1.        ]
#  [1.        ]
#  ...
#  [0.4344596 ]
#  [1.        ]
#  [1.        ]]
# <style type="text/css">
# #T_82b93_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_82b93_row0_col1, #T_82b93_row0_col2, #T_82b93_row1_col0, #T_82b93_row1_col1, #T_82b93_row1_col2, #T_82b93_row2_col1, #T_82b93_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_82b93_row2_col0 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# </style>
# <table id="T_82b93_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >centro</th>
#       <th class="col_heading level0 col1" >direita</th>
#       <th class="col_heading level0 col2" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82b93_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_82b93_row0_col0" class="data row0 col0" >601</td>
#       <td id="T_82b93_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_82b93_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_82b93_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_82b93_row1_col0" class="data row1 col0" >587</td>
#       <td id="T_82b93_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_82b93_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_82b93_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_82b93_row2_col0" class="data row2 col0" >597</td>
#       <td id="T_82b93_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_82b93_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1cc05_row0_col0, #T_1cc05_row0_col1, #T_1cc05_row0_col2, #T_1cc05_row3_col1, #T_1cc05_row5_col0, #T_1cc05_row5_col1, #T_1cc05_row5_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_1cc05_row1_col0, #T_1cc05_row1_col1, #T_1cc05_row1_col2, #T_1cc05_row2_col0, #T_1cc05_row2_col1, #T_1cc05_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1cc05_row3_col0 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_1cc05_row3_col2 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_1cc05_row4_col0, #T_1cc05_row4_col1, #T_1cc05_row4_col2 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1cc05_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cc05_level0_row0" class="row_heading level0 row0" >centro</th>
#       <td id="T_1cc05_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1cc05_row0_col1" class="data row0 col1" >0.336695</td>
#       <td id="T_1cc05_row0_col2" class="data row0 col2" >0.503772</td>
#       <td id="T_1cc05_row0_col3" class="data row0 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_1cc05_level0_row1" class="row_heading level0 row1" >direita</th>
#       <td id="T_1cc05_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_1cc05_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_1cc05_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_1cc05_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1cc05_level0_row2" class="row_heading level0 row2" >esquerda</th>
#       <td id="T_1cc05_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_1cc05_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_1cc05_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_1cc05_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1cc05_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_1cc05_row3_col0" class="data row3 col0" >0.336695</td>
#       <td id="T_1cc05_row3_col1" class="data row3 col1" >0.336695</td>
#       <td id="T_1cc05_row3_col2" class="data row3 col2" >0.336695</td>
#       <td id="T_1cc05_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1cc05_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_1cc05_row4_col0" class="data row4 col0" >0.333333</td>
#       <td id="T_1cc05_row4_col1" class="data row4 col1" >0.112232</td>
#       <td id="T_1cc05_row4_col2" class="data row4 col2" >0.167924</td>
#       <td id="T_1cc05_row4_col3" class="data row4 col3" >1785</td>
#     </tr>
#     <tr>
#       <th id="T_1cc05_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_1cc05_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_1cc05_row5_col1" class="data row5 col1" >0.336695</td>
#       <td id="T_1cc05_row5_col2" class="data row5 col2" >0.503772</td>
#       <td id="T_1cc05_row5_col3" class="data row5 col3" >1785</td>
#     </tr>
#   </tbody>
# </table>
