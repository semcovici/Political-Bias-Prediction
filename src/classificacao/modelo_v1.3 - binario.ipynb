# %%
# == importando bibliotecas == 

import pandas as pd
import numpy as np
from tqdm import tqdm
import string
import textblob
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection, metrics
from sklearn import preprocessing
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from tensorflow import keras
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras import models, optimizers
# from tensorflow.keras.layers import LSTM, Convolution1D, GRU, Dense, Dropout, Input, Embedding, SpatialDropout1D, Bidirectional
from tensorflow.keras.layers import *
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')

# %%
# # == download do modelo pré-treinado de word embedding == 

# inglês
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.vec.gz
# !gunzip cc.en.300.vec.gz
# !mv cc.en.300.vec ../../dataset/fasttext_word_embedding/en_word_embedding.vec

# português
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.pt.300.vec.gz
# !gunzip cc.pt.300.vec.gz
# !mv cc.pt.300.vec ../../fasttext_word_embedding/pt_word_embedding.vec

# %%
# == variáveis == 

path_pt = 'dados_treino_ingles'
path_en = 'dados_treino_pt_google_trad'
path = path_pt
word_embedding_en = 'en_word_embedding.vec'
word_embedding_pt = 'pt_word_embedding.vec'
word_embedding = word_embedding_pt

# %%
# == importar dados ==

df = pd.read_parquet(f'../../dataset/processed/artigos_tratados/artigos_tratados.parquet')

# %%
# == remover partidos de centro == 

df = df[df.Vies != 'centro']

# %%
# == contagem de artigos por viés ==

df[df.Vies == 'direita'].Partido.value_counts() / df[df.Vies == 'direita'].shape[0]
df[df.Vies == 'esquerda'].Partido.value_counts() / df[df.Vies == 'esquerda'].shape[0]
# Out:
# PL              0.613593
# Novo            0.223720
# PP              0.111090
# União Brasil    0.051598
# Name: Partido, dtype: float64
# PSTU     0.252128
# PCDoB    0.244021
# PCB      0.225780
# PT       0.224970
# Rede     0.047021
# PSOL     0.006080
# Name: Partido, dtype: float64

# %%
# == contagem de artigos por viés ==

df[df.Vies == 'direita'].Partido.value_counts() / df.shape[0]
df[df.Vies == 'esquerda'].Partido.value_counts() / df.shape[0]
# Out:
# PL              0.416003
# Novo            0.151677
# PP              0.075317
# União Brasil    0.034982
# Name: Partido, dtype: float64
# PSTU     0.081190
# PCDoB    0.078580
# PCB      0.072706
# PT       0.072445
# Rede     0.015142
# PSOL     0.001958
# Name: Partido, dtype: float64

# %%
# == separar aproximadamente 8% de cada viés para usar como validação ==

train = df[~df.Partido.isin(['PP', 'PCB'])]
valid = df[df.Partido.isin(['PP', 'PCB'])]

# %%
# == conjunto treino e teste == 

train[['Partido', 'Vies']].value_counts().to_frame()
valid[['Partido', 'Vies']].value_counts().to_frame()
# Out:
#                           0
# Partido      Vies
# PL           direita   3385
# Novo         direita   1197
# PSTU         esquerda   627
# PCDoB        esquerda   602
# PT           esquerda   597
# União Brasil direita    284
# Rede         esquerda   124
# PSOL         esquerda    15
#                     0
# Partido Vies
# PCB     esquerda  617
# PP      direita   587

# %%
# == train & test split ==

X_train, X_valid, y_train, y_valid = train.Conteudo, valid.Conteudo, train.Vies, valid.Vies

# %%
# == label encoding do rótulo == 

encoder = preprocessing.LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_valid = encoder.fit_transform(y_valid)

# %%
# == label das classes == 

encoder.classes_
encoder.inverse_transform([0,1])
# Out:
# array(['direita', 'esquerda'], dtype=object)
# array(['direita', 'esquerda'], dtype=object)

# %%
# == count vectorizer ==

count_vect = CountVectorizer(
    analyzer='word', 
    token_pattern=r'\w{1,}'
)
count_vect.fit(df.Conteudo)
X_train_count =  count_vect.transform(X_train)
X_valid_count =  count_vect.transform(X_valid)
# Out:
# CountVectorizer(token_pattern='\\w{1,}')

# %%
# == word level tf-idf ==

tfidf_vect = TfidfVectorizer(
    analyzer='word', 
    max_features=300
)
tfidf_vect.fit(df.Conteudo)
X_train_tfidf = tfidf_vect.transform(X_train)
X_valid_tfidf = tfidf_vect.transform(X_valid)
# Out:
# TfidfVectorizer(max_features=300)

# %%
# == ngram level tf-idf ==

tfidf_vect_ngram = TfidfVectorizer(
    analyzer='word', 
    ngram_range=(1,3), 
    max_features=100
)
tfidf_vect_ngram.fit(df.Conteudo)
X_train_tfidf_ngram =  tfidf_vect_ngram.transform(X_train)
X_valid_tfidf_ngram =  tfidf_vect_ngram.transform(X_valid)
# Out:
# TfidfVectorizer(max_features=100, ngram_range=(1, 3))

# %%
# == characters level tf-idf ==

tfidf_vect_ngram_chars = TfidfVectorizer(
    analyzer='char', 
    ngram_range=(1,3), 
    max_features=100
)
tfidf_vect_ngram_chars.fit(df.Conteudo)
X_train_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(X_train) 
X_valid_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(X_valid)
# Out:
# TfidfVectorizer(analyzer='char', max_features=100, ngram_range=(1, 3))

# %%
# == fazer load do vetor pré-treinado de word embedding ==  

embedding_idx = {}
for i, line in tqdm(enumerate(open(f'../../dataset/fasttext_word_embedding/{word_embedding}'))):
    values = line.split()
    embedding_idx[values[0]] = np.asarray(values[1:] , dtype='float32')
# Out:
# 2000001it [01:45, 19013.31it/s]

# %%
# == criar um tokenizador ==

token = text.Tokenizer()
token.fit_on_texts(df.Conteudo)
word_index = token.word_index

# %%
# == converter texto para sequência de tokens e preenchê-los para ter o mesmo tamanho == 

X_train_seq = sequence.pad_sequences(token.texts_to_sequences(X_train), maxlen=150)
X_valid_seq = sequence.pad_sequences(token.texts_to_sequences(X_valid), maxlen=150)

# %%
# == criar map de token-embedding ==

embedding_matrix = np.zeros((len(word_index) + 1, 300))
for word, i in word_index.items():
    embedding_vector = embedding_idx.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# == método para trieinar o modelo == 

def train_model(model, X_train, y_train, X_valid, is_neural, return_model = False):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    
    print(y_pred)
    if is_neural: 
        y_pred = np.round(y_pred)
        
    cr = pd.DataFrame(
        classification_report(
            y_pred, 
            y_valid, 
            digits=2,
            output_dict=True,
            target_names=encoder.inverse_transform([0,1])
        )
    ).T
    cr['support'] = cr.support.apply(int)
    
    cm = pd.DataFrame(
        confusion_matrix(
            y_valid,
            y_pred
        )
    )
    cm.columns = ['direita', 'esquerda']
    cm.index = ['direita', 'esquerda']
    
    if return_model:
        return cr, cm, model
    return cr, cm

# %%
# == logistic regression == 

model = LogisticRegression(solver='liblinear')

print('Logistic Regression, Count Vectors:')
cr, cm = train_model(
    model, 
    X_train_count, 
    y_train, 
    X_valid_count, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Logistic Regression, WordLevel TF-IDF: ")
cr, cm = train_model(
    model, 
    X_train_tfidf, 
    y_train, 
    X_valid_tfidf, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Logistic Regression, N-Gram Vectors: ")
cr, cm = train_model(
    model, 
    X_train_tfidf_ngram, 
    y_train, 
    X_valid_tfidf_ngram, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Logistic Regression, CharLevel Vectors: ")
cr, cm = train_model(
    model, 
    X_train_tfidf_ngram_chars, 
    y_train, 
    X_valid_tfidf_ngram_chars, 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# Logistic Regression, Count Vectors:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_c04b5_row0_col0, #T_c04b5_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c04b5_row0_col1, #T_c04b5_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c04b5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c04b5_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_c04b5_row0_col0" class="data row0 col0" >584</td>
#       <td id="T_c04b5_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c04b5_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_c04b5_row1_col0" class="data row1 col0" >129</td>
#       <td id="T_c04b5_row1_col1" class="data row1 col1" >488</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4f89f_row0_col0, #T_4f89f_row0_col2, #T_4f89f_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_4f89f_row0_col1, #T_4f89f_row1_col0, #T_4f89f_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_4f89f_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_4f89f_row2_col1, #T_4f89f_row4_col1 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_4f89f_row2_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_4f89f_row3_col0, #T_4f89f_row3_col1, #T_4f89f_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_4f89f_row4_col0, #T_4f89f_row4_col2 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4f89f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f89f_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_4f89f_row0_col0" class="data row0 col0" >0.994889</td>
#       <td id="T_4f89f_row0_col1" class="data row0 col1" >0.819074</td>
#       <td id="T_4f89f_row0_col2" class="data row0 col2" >0.898462</td>
#       <td id="T_4f89f_row0_col3" class="data row0 col3" >713</td>
#     </tr>
#     <tr>
#       <th id="T_4f89f_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_4f89f_row1_col0" class="data row1 col0" >0.790924</td>
#       <td id="T_4f89f_row1_col1" class="data row1 col1" >0.993890</td>
#       <td id="T_4f89f_row1_col2" class="data row1 col2" >0.880866</td>
#       <td id="T_4f89f_row1_col3" class="data row1 col3" >491</td>
#     </tr>
#     <tr>
#       <th id="T_4f89f_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_4f89f_row2_col0" class="data row2 col0" >0.890365</td>
#       <td id="T_4f89f_row2_col1" class="data row2 col1" >0.890365</td>
#       <td id="T_4f89f_row2_col2" class="data row2 col2" >0.890365</td>
#       <td id="T_4f89f_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4f89f_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_4f89f_row3_col0" class="data row3 col0" >0.892907</td>
#       <td id="T_4f89f_row3_col1" class="data row3 col1" >0.906482</td>
#       <td id="T_4f89f_row3_col2" class="data row3 col2" >0.889664</td>
#       <td id="T_4f89f_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_4f89f_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_4f89f_row4_col0" class="data row4 col0" >0.911711</td>
#       <td id="T_4f89f_row4_col1" class="data row4 col1" >0.890365</td>
#       <td id="T_4f89f_row4_col2" class="data row4 col2" >0.891286</td>
#       <td id="T_4f89f_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>
# Logistic Regression, WordLevel TF-IDF:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_b8911_row0_col0, #T_b8911_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_b8911_row0_col1, #T_b8911_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b8911_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8911_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_b8911_row0_col0" class="data row0 col0" >576</td>
#       <td id="T_b8911_row0_col1" class="data row0 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_b8911_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_b8911_row1_col0" class="data row1 col0" >184</td>
#       <td id="T_b8911_row1_col1" class="data row1 col1" >433</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1509a_row0_col0, #T_1509a_row0_col2, #T_1509a_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_1509a_row0_col1, #T_1509a_row1_col0, #T_1509a_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_1509a_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_1509a_row2_col1, #T_1509a_row4_col1 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_1509a_row2_col2 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_1509a_row3_col0, #T_1509a_row3_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_1509a_row3_col2 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_1509a_row4_col0, #T_1509a_row4_col2 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1509a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1509a_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_1509a_row0_col0" class="data row0 col0" >0.981261</td>
#       <td id="T_1509a_row0_col1" class="data row0 col1" >0.757895</td>
#       <td id="T_1509a_row0_col2" class="data row0 col2" >0.855234</td>
#       <td id="T_1509a_row0_col3" class="data row0 col3" >760</td>
#     </tr>
#     <tr>
#       <th id="T_1509a_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_1509a_row1_col0" class="data row1 col0" >0.701783</td>
#       <td id="T_1509a_row1_col1" class="data row1 col1" >0.975225</td>
#       <td id="T_1509a_row1_col2" class="data row1 col2" >0.816211</td>
#       <td id="T_1509a_row1_col3" class="data row1 col3" >444</td>
#     </tr>
#     <tr>
#       <th id="T_1509a_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_1509a_row2_col0" class="data row2 col0" >0.838040</td>
#       <td id="T_1509a_row2_col1" class="data row2 col1" >0.838040</td>
#       <td id="T_1509a_row2_col2" class="data row2 col2" >0.838040</td>
#       <td id="T_1509a_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1509a_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_1509a_row3_col0" class="data row3 col0" >0.841522</td>
#       <td id="T_1509a_row3_col1" class="data row3 col1" >0.866560</td>
#       <td id="T_1509a_row3_col2" class="data row3 col2" >0.835722</td>
#       <td id="T_1509a_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_1509a_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_1509a_row4_col0" class="data row4 col0" >0.878197</td>
#       <td id="T_1509a_row4_col1" class="data row4 col1" >0.838040</td>
#       <td id="T_1509a_row4_col2" class="data row4 col2" >0.840843</td>
#       <td id="T_1509a_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>
# Logistic Regression, N-Gram Vectors:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_e0745_row0_col0, #T_e0745_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e0745_row0_col1, #T_e0745_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e0745_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0745_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_e0745_row0_col0" class="data row0 col0" >577</td>
#       <td id="T_e0745_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e0745_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_e0745_row1_col0" class="data row1 col0" >188</td>
#       <td id="T_e0745_row1_col1" class="data row1 col1" >429</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_68b69_row0_col0, #T_68b69_row0_col2, #T_68b69_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_68b69_row0_col1, #T_68b69_row1_col0, #T_68b69_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_68b69_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_68b69_row2_col1, #T_68b69_row4_col1 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_68b69_row2_col2 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_68b69_row3_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_68b69_row3_col1, #T_68b69_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_68b69_row4_col0, #T_68b69_row4_col2 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_68b69_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68b69_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_68b69_row0_col0" class="data row0 col0" >0.982964</td>
#       <td id="T_68b69_row0_col1" class="data row0 col1" >0.754248</td>
#       <td id="T_68b69_row0_col2" class="data row0 col2" >0.853550</td>
#       <td id="T_68b69_row0_col3" class="data row0 col3" >765</td>
#     </tr>
#     <tr>
#       <th id="T_68b69_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_68b69_row1_col0" class="data row1 col0" >0.695300</td>
#       <td id="T_68b69_row1_col1" class="data row1 col1" >0.977221</td>
#       <td id="T_68b69_row1_col2" class="data row1 col2" >0.812500</td>
#       <td id="T_68b69_row1_col3" class="data row1 col3" >439</td>
#     </tr>
#     <tr>
#       <th id="T_68b69_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_68b69_row2_col0" class="data row2 col0" >0.835548</td>
#       <td id="T_68b69_row2_col1" class="data row2 col1" >0.835548</td>
#       <td id="T_68b69_row2_col2" class="data row2 col2" >0.835548</td>
#       <td id="T_68b69_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_68b69_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_68b69_row3_col0" class="data row3 col0" >0.839132</td>
#       <td id="T_68b69_row3_col1" class="data row3 col1" >0.865735</td>
#       <td id="T_68b69_row3_col2" class="data row3 col2" >0.833025</td>
#       <td id="T_68b69_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_68b69_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_68b69_row4_col0" class="data row4 col0" >0.878077</td>
#       <td id="T_68b69_row4_col1" class="data row4 col1" >0.835548</td>
#       <td id="T_68b69_row4_col2" class="data row4 col2" >0.838583</td>
#       <td id="T_68b69_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>
# Logistic Regression, CharLevel Vectors:
# [0 0 0 ... 0 0 0]
# <style type="text/css">
# #T_e8849_row0_col0, #T_e8849_row0_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_e8849_row1_col0, #T_e8849_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_e8849_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8849_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_e8849_row0_col0" class="data row0 col0" >586</td>
#       <td id="T_e8849_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8849_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_e8849_row1_col0" class="data row1 col0" >609</td>
#       <td id="T_e8849_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_524ec_row0_col0, #T_524ec_row0_col2, #T_524ec_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_524ec_row0_col1, #T_524ec_row1_col0, #T_524ec_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_524ec_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_524ec_row2_col1, #T_524ec_row4_col1 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_524ec_row2_col2 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_524ec_row3_col0, #T_524ec_row3_col1, #T_524ec_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_524ec_row4_col0, #T_524ec_row4_col2 {
#   background-color: #fbe723;
#   color: #000000;
# }
# </style>
# <table id="T_524ec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_524ec_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_524ec_row0_col0" class="data row0 col0" >0.998296</td>
#       <td id="T_524ec_row0_col1" class="data row0 col1" >0.490377</td>
#       <td id="T_524ec_row0_col2" class="data row0 col2" >0.657688</td>
#       <td id="T_524ec_row0_col3" class="data row0 col3" >1195</td>
#     </tr>
#     <tr>
#       <th id="T_524ec_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_524ec_row1_col0" class="data row1 col0" >0.012966</td>
#       <td id="T_524ec_row1_col1" class="data row1 col1" >0.888889</td>
#       <td id="T_524ec_row1_col2" class="data row1 col2" >0.025559</td>
#       <td id="T_524ec_row1_col3" class="data row1 col3" >9</td>
#     </tr>
#     <tr>
#       <th id="T_524ec_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_524ec_row2_col0" class="data row2 col0" >0.493355</td>
#       <td id="T_524ec_row2_col1" class="data row2 col1" >0.493355</td>
#       <td id="T_524ec_row2_col2" class="data row2 col2" >0.493355</td>
#       <td id="T_524ec_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_524ec_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_524ec_row3_col0" class="data row3 col0" >0.505631</td>
#       <td id="T_524ec_row3_col1" class="data row3 col1" >0.689633</td>
#       <td id="T_524ec_row3_col2" class="data row3 col2" >0.341624</td>
#       <td id="T_524ec_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_524ec_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_524ec_row4_col0" class="data row4 col0" >0.990931</td>
#       <td id="T_524ec_row4_col1" class="data row4 col1" >0.493355</td>
#       <td id="T_524ec_row4_col2" class="data row4 col2" >0.652963</td>
#       <td id="T_524ec_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == support vector machine (svm)

print ("Suport Vector Machine, N-Gram Vectors: ")
cr, cm = train_model(
    SVC(), 
    X_train_tfidf_ngram, 
    y_train, 
    X_valid_tfidf_ngram,
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# Suport Vector Machine, N-Gram Vectors:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_486a7_row0_col0, #T_486a7_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_486a7_row0_col1, #T_486a7_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_486a7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_486a7_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_486a7_row0_col0" class="data row0 col0" >575</td>
#       <td id="T_486a7_row0_col1" class="data row0 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_486a7_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_486a7_row1_col0" class="data row1 col0" >138</td>
#       <td id="T_486a7_row1_col1" class="data row1 col1" >479</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8070b_row0_col0, #T_8070b_row0_col2, #T_8070b_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8070b_row0_col1, #T_8070b_row1_col0, #T_8070b_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8070b_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_8070b_row2_col1, #T_8070b_row4_col1 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_8070b_row2_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_8070b_row3_col0 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_8070b_row3_col1, #T_8070b_row3_col2 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_8070b_row4_col0, #T_8070b_row4_col2 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8070b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8070b_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_8070b_row0_col0" class="data row0 col0" >0.979557</td>
#       <td id="T_8070b_row0_col1" class="data row0 col1" >0.806452</td>
#       <td id="T_8070b_row0_col2" class="data row0 col2" >0.884615</td>
#       <td id="T_8070b_row0_col3" class="data row0 col3" >713</td>
#     </tr>
#     <tr>
#       <th id="T_8070b_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_8070b_row1_col0" class="data row1 col0" >0.776337</td>
#       <td id="T_8070b_row1_col1" class="data row1 col1" >0.975560</td>
#       <td id="T_8070b_row1_col2" class="data row1 col2" >0.864621</td>
#       <td id="T_8070b_row1_col3" class="data row1 col3" >491</td>
#     </tr>
#     <tr>
#       <th id="T_8070b_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_8070b_row2_col0" class="data row2 col0" >0.875415</td>
#       <td id="T_8070b_row2_col1" class="data row2 col1" >0.875415</td>
#       <td id="T_8070b_row2_col2" class="data row2 col2" >0.875415</td>
#       <td id="T_8070b_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8070b_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_8070b_row3_col0" class="data row3 col0" >0.877947</td>
#       <td id="T_8070b_row3_col1" class="data row3 col1" >0.891006</td>
#       <td id="T_8070b_row3_col2" class="data row3 col2" >0.874618</td>
#       <td id="T_8070b_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_8070b_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_8070b_row4_col0" class="data row4 col0" >0.896682</td>
#       <td id="T_8070b_row4_col1" class="data row4 col1" >0.875415</td>
#       <td id="T_8070b_row4_col2" class="data row4 col2" >0.876462</td>
#       <td id="T_8070b_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == random forest classifier == 

print ("Random Forest, Count Vectors: ")
cr, cm = train_model(
    RandomForestClassifier(
        n_estimators=500
    ), 
    X_train_count, 
    y_train, 
    X_valid_count,
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("Random Forest, WordLevel TF-IDF: ")
cr, cm = train_model(
    RandomForestClassifier(
        n_estimators=500
    ), 
    X_train_tfidf, 
    y_train, 
    X_valid_tfidf,
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# Random Forest, Count Vectors:
# [0 1 1 ... 0 0 0]
# <style type="text/css">
# #T_105b0_row0_col0, #T_105b0_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_105b0_row0_col1, #T_105b0_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_105b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_105b0_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_105b0_row0_col0" class="data row0 col0" >585</td>
#       <td id="T_105b0_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_105b0_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_105b0_row1_col0" class="data row1 col0" >299</td>
#       <td id="T_105b0_row1_col1" class="data row1 col1" >318</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7efc6_row0_col0, #T_7efc6_row0_col2, #T_7efc6_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7efc6_row0_col1, #T_7efc6_row1_col0, #T_7efc6_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_7efc6_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_7efc6_row2_col1, #T_7efc6_row4_col1 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_7efc6_row2_col2 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_7efc6_row3_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_7efc6_row3_col1, #T_7efc6_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_7efc6_row4_col0, #T_7efc6_row4_col2 {
#   background-color: #54c568;
#   color: #000000;
# }
# </style>
# <table id="T_7efc6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7efc6_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_7efc6_row0_col0" class="data row0 col0" >0.996593</td>
#       <td id="T_7efc6_row0_col1" class="data row0 col1" >0.661765</td>
#       <td id="T_7efc6_row0_col2" class="data row0 col2" >0.795377</td>
#       <td id="T_7efc6_row0_col3" class="data row0 col3" >884</td>
#     </tr>
#     <tr>
#       <th id="T_7efc6_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_7efc6_row1_col0" class="data row1 col0" >0.515397</td>
#       <td id="T_7efc6_row1_col1" class="data row1 col1" >0.993750</td>
#       <td id="T_7efc6_row1_col2" class="data row1 col2" >0.678762</td>
#       <td id="T_7efc6_row1_col3" class="data row1 col3" >320</td>
#     </tr>
#     <tr>
#       <th id="T_7efc6_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_7efc6_row2_col0" class="data row2 col0" >0.750000</td>
#       <td id="T_7efc6_row2_col1" class="data row2 col1" >0.750000</td>
#       <td id="T_7efc6_row2_col2" class="data row2 col2" >0.750000</td>
#       <td id="T_7efc6_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7efc6_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_7efc6_row3_col0" class="data row3 col0" >0.755995</td>
#       <td id="T_7efc6_row3_col1" class="data row3 col1" >0.827757</td>
#       <td id="T_7efc6_row3_col2" class="data row3 col2" >0.737070</td>
#       <td id="T_7efc6_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_7efc6_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_7efc6_row4_col0" class="data row4 col0" >0.868700</td>
#       <td id="T_7efc6_row4_col1" class="data row4 col1" >0.750000</td>
#       <td id="T_7efc6_row4_col2" class="data row4 col2" >0.764383</td>
#       <td id="T_7efc6_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>
# Random Forest, WordLevel TF-IDF:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_888d3_row0_col0, #T_888d3_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_888d3_row0_col1, #T_888d3_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_888d3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_888d3_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_888d3_row0_col0" class="data row0 col0" >584</td>
#       <td id="T_888d3_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_888d3_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_888d3_row1_col0" class="data row1 col0" >204</td>
#       <td id="T_888d3_row1_col1" class="data row1 col1" >413</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_178c9_row0_col0, #T_178c9_row0_col2, #T_178c9_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_178c9_row0_col1, #T_178c9_row1_col0, #T_178c9_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_178c9_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_178c9_row2_col1, #T_178c9_row4_col1 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_178c9_row2_col2 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_178c9_row3_col0, #T_178c9_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_178c9_row3_col1 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_178c9_row4_col0, #T_178c9_row4_col2 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_178c9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_178c9_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_178c9_row0_col0" class="data row0 col0" >0.994889</td>
#       <td id="T_178c9_row0_col1" class="data row0 col1" >0.741117</td>
#       <td id="T_178c9_row0_col2" class="data row0 col2" >0.849455</td>
#       <td id="T_178c9_row0_col3" class="data row0 col3" >788</td>
#     </tr>
#     <tr>
#       <th id="T_178c9_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_178c9_row1_col0" class="data row1 col0" >0.669368</td>
#       <td id="T_178c9_row1_col1" class="data row1 col1" >0.992788</td>
#       <td id="T_178c9_row1_col2" class="data row1 col2" >0.799613</td>
#       <td id="T_178c9_row1_col3" class="data row1 col3" >416</td>
#     </tr>
#     <tr>
#       <th id="T_178c9_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_178c9_row2_col0" class="data row2 col0" >0.828073</td>
#       <td id="T_178c9_row2_col1" class="data row2 col1" >0.828073</td>
#       <td id="T_178c9_row2_col2" class="data row2 col2" >0.828073</td>
#       <td id="T_178c9_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_178c9_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_178c9_row3_col0" class="data row3 col0" >0.832129</td>
#       <td id="T_178c9_row3_col1" class="data row3 col1" >0.866953</td>
#       <td id="T_178c9_row3_col2" class="data row3 col2" >0.824534</td>
#       <td id="T_178c9_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_178c9_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_178c9_row4_col0" class="data row4 col0" >0.882417</td>
#       <td id="T_178c9_row4_col1" class="data row4 col1" >0.828073</td>
#       <td id="T_178c9_row4_col2" class="data row4 col2" >0.832233</td>
#       <td id="T_178c9_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == gradient boost == 

model = XGBClassifier(
    use_label_encoder=False, 
    eval_metric='mlogloss',
    learning_rate=0.01,
    n_estimators=500
)

print ("XGBClassifier, Count Vectors: ")
cr, cm = train_model(
    model, 
    X_train_count.tocsc(), 
    y_train, 
    X_valid_count.tocsc(), 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("XGBClassifier, WordLevel TF-IDF: ")
cr, cm = train_model(
    model, 
    X_train_tfidf.tocsc(), 
    y_train, 
    X_valid_tfidf.tocsc(), 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)

print ("XGBClassifier, CharLevel Vectors: ")
cr, cm = train_model(
    model, 
    X_train_tfidf_ngram_chars.tocsc(), 
    y_train, 
    X_valid_tfidf_ngram_chars.tocsc(), 
    False
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# XGBClassifier, Count Vectors:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_33846_row0_col0, #T_33846_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_33846_row0_col1, #T_33846_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_33846_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33846_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_33846_row0_col0" class="data row0 col0" >580</td>
#       <td id="T_33846_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_33846_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_33846_row1_col0" class="data row1 col0" >209</td>
#       <td id="T_33846_row1_col1" class="data row1 col1" >408</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9169e_row0_col0, #T_9169e_row0_col2, #T_9169e_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9169e_row0_col1, #T_9169e_row1_col0, #T_9169e_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_9169e_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_9169e_row2_col1, #T_9169e_row4_col1 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_9169e_row2_col2 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_9169e_row3_col0, #T_9169e_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_9169e_row3_col1 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_9169e_row4_col0, #T_9169e_row4_col2 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9169e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9169e_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_9169e_row0_col0" class="data row0 col0" >0.988075</td>
#       <td id="T_9169e_row0_col1" class="data row0 col1" >0.735108</td>
#       <td id="T_9169e_row0_col2" class="data row0 col2" >0.843023</td>
#       <td id="T_9169e_row0_col3" class="data row0 col3" >789</td>
#     </tr>
#     <tr>
#       <th id="T_9169e_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_9169e_row1_col0" class="data row1 col0" >0.661264</td>
#       <td id="T_9169e_row1_col1" class="data row1 col1" >0.983133</td>
#       <td id="T_9169e_row1_col2" class="data row1 col2" >0.790698</td>
#       <td id="T_9169e_row1_col3" class="data row1 col3" >415</td>
#     </tr>
#     <tr>
#       <th id="T_9169e_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_9169e_row2_col0" class="data row2 col0" >0.820598</td>
#       <td id="T_9169e_row2_col1" class="data row2 col1" >0.820598</td>
#       <td id="T_9169e_row2_col2" class="data row2 col2" >0.820598</td>
#       <td id="T_9169e_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9169e_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_9169e_row3_col0" class="data row3 col0" >0.824670</td>
#       <td id="T_9169e_row3_col1" class="data row3 col1" >0.859120</td>
#       <td id="T_9169e_row3_col2" class="data row3 col2" >0.816860</td>
#       <td id="T_9169e_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_9169e_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_9169e_row4_col0" class="data row4 col0" >0.875428</td>
#       <td id="T_9169e_row4_col1" class="data row4 col1" >0.820598</td>
#       <td id="T_9169e_row4_col2" class="data row4 col2" >0.824987</td>
#       <td id="T_9169e_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>
# XGBClassifier, WordLevel TF-IDF:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_7b3a9_row0_col0, #T_7b3a9_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7b3a9_row0_col1, #T_7b3a9_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7b3a9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b3a9_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_7b3a9_row0_col0" class="data row0 col0" >563</td>
#       <td id="T_7b3a9_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_7b3a9_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_7b3a9_row1_col0" class="data row1 col0" >113</td>
#       <td id="T_7b3a9_row1_col1" class="data row1 col1" >504</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8a233_row0_col0, #T_8a233_row0_col2, #T_8a233_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8a233_row0_col1, #T_8a233_row1_col0, #T_8a233_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8a233_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_8a233_row2_col1, #T_8a233_row4_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_8a233_row2_col2 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_8a233_row3_col0, #T_8a233_row3_col2 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_8a233_row3_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_8a233_row4_col0, #T_8a233_row4_col2 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8a233_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a233_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_8a233_row0_col0" class="data row0 col0" >0.959114</td>
#       <td id="T_8a233_row0_col1" class="data row0 col1" >0.832840</td>
#       <td id="T_8a233_row0_col2" class="data row0 col2" >0.891528</td>
#       <td id="T_8a233_row0_col3" class="data row0 col3" >676</td>
#     </tr>
#     <tr>
#       <th id="T_8a233_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_8a233_row1_col0" class="data row1 col0" >0.816856</td>
#       <td id="T_8a233_row1_col1" class="data row1 col1" >0.954545</td>
#       <td id="T_8a233_row1_col2" class="data row1 col2" >0.880349</td>
#       <td id="T_8a233_row1_col3" class="data row1 col3" >528</td>
#     </tr>
#     <tr>
#       <th id="T_8a233_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_8a233_row2_col0" class="data row2 col0" >0.886213</td>
#       <td id="T_8a233_row2_col1" class="data row2 col1" >0.886213</td>
#       <td id="T_8a233_row2_col2" class="data row2 col2" >0.886213</td>
#       <td id="T_8a233_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8a233_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_8a233_row3_col0" class="data row3 col0" >0.887985</td>
#       <td id="T_8a233_row3_col1" class="data row3 col1" >0.893693</td>
#       <td id="T_8a233_row3_col2" class="data row3 col2" >0.885939</td>
#       <td id="T_8a233_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_8a233_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_8a233_row4_col0" class="data row4 col0" >0.896728</td>
#       <td id="T_8a233_row4_col1" class="data row4 col1" >0.886213</td>
#       <td id="T_8a233_row4_col2" class="data row4 col2" >0.886626</td>
#       <td id="T_8a233_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>
# XGBClassifier, CharLevel Vectors:
# [1 0 0 ... 0 0 0]
# <style type="text/css">
# #T_04bf1_row0_col0, #T_04bf1_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_04bf1_row0_col1, #T_04bf1_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_04bf1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04bf1_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_04bf1_row0_col0" class="data row0 col0" >587</td>
#       <td id="T_04bf1_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04bf1_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_04bf1_row1_col0" class="data row1 col0" >521</td>
#       <td id="T_04bf1_row1_col1" class="data row1 col1" >96</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e65ef_row0_col0, #T_e65ef_row0_col2, #T_e65ef_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e65ef_row0_col1, #T_e65ef_row1_col0, #T_e65ef_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_e65ef_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_e65ef_row2_col1, #T_e65ef_row4_col1 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_e65ef_row2_col2 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_e65ef_row3_col0, #T_e65ef_row3_col1, #T_e65ef_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_e65ef_row4_col0, #T_e65ef_row4_col2 {
#   background-color: #cae11f;
#   color: #000000;
# }
# </style>
# <table id="T_e65ef_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e65ef_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_e65ef_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e65ef_row0_col1" class="data row0 col1" >0.529783</td>
#       <td id="T_e65ef_row0_col2" class="data row0 col2" >0.692625</td>
#       <td id="T_e65ef_row0_col3" class="data row0 col3" >1108</td>
#     </tr>
#     <tr>
#       <th id="T_e65ef_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_e65ef_row1_col0" class="data row1 col0" >0.155592</td>
#       <td id="T_e65ef_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e65ef_row1_col2" class="data row1 col2" >0.269285</td>
#       <td id="T_e65ef_row1_col3" class="data row1 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_e65ef_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_e65ef_row2_col0" class="data row2 col0" >0.567276</td>
#       <td id="T_e65ef_row2_col1" class="data row2 col1" >0.567276</td>
#       <td id="T_e65ef_row2_col2" class="data row2 col2" >0.567276</td>
#       <td id="T_e65ef_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e65ef_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_e65ef_row3_col0" class="data row3 col0" >0.577796</td>
#       <td id="T_e65ef_row3_col1" class="data row3 col1" >0.764892</td>
#       <td id="T_e65ef_row3_col2" class="data row3 col2" >0.480955</td>
#       <td id="T_e65ef_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_e65ef_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_e65ef_row4_col0" class="data row4 col0" >0.932672</td>
#       <td id="T_e65ef_row4_col1" class="data row4 col1" >0.567276</td>
#       <td id="T_e65ef_row4_col2" class="data row4 col2" >0.658871</td>
#       <td id="T_e65ef_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>

# %%
# == testando esse modelo e obtendo FI == 

print ("XGBClassifier, WordLevel TF-IDF: ")
cr, cm, model = train_model(
    model, 
    X_train_tfidf.tocsc(), 
    y_train, 
    X_valid_tfidf.tocsc(), 
    False,
    True
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# XGBClassifier, WordLevel TF-IDF:
# [1 1 1 ... 0 0 0]
# <style type="text/css">
# #T_c1288_row0_col0, #T_c1288_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c1288_row0_col1, #T_c1288_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c1288_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1288_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_c1288_row0_col0" class="data row0 col0" >565</td>
#       <td id="T_c1288_row0_col1" class="data row0 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_c1288_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_c1288_row1_col0" class="data row1 col0" >108</td>
#       <td id="T_c1288_row1_col1" class="data row1 col1" >509</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cb73e_row0_col0, #T_cb73e_row0_col2, #T_cb73e_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_cb73e_row0_col1, #T_cb73e_row1_col0, #T_cb73e_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_cb73e_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_cb73e_row2_col1, #T_cb73e_row4_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_cb73e_row2_col2 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_cb73e_row3_col0, #T_cb73e_row3_col1, #T_cb73e_row3_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_cb73e_row4_col0, #T_cb73e_row4_col2 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb73e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb73e_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_cb73e_row0_col0" class="data row0 col0" >0.962521</td>
#       <td id="T_cb73e_row0_col1" class="data row0 col1" >0.839525</td>
#       <td id="T_cb73e_row0_col2" class="data row0 col2" >0.896825</td>
#       <td id="T_cb73e_row0_col3" class="data row0 col3" >673</td>
#     </tr>
#     <tr>
#       <th id="T_cb73e_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_cb73e_row1_col0" class="data row1 col0" >0.824959</td>
#       <td id="T_cb73e_row1_col1" class="data row1 col1" >0.958569</td>
#       <td id="T_cb73e_row1_col2" class="data row1 col2" >0.886760</td>
#       <td id="T_cb73e_row1_col3" class="data row1 col3" >531</td>
#     </tr>
#     <tr>
#       <th id="T_cb73e_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_cb73e_row2_col0" class="data row2 col0" >0.892027</td>
#       <td id="T_cb73e_row2_col1" class="data row2 col1" >0.892027</td>
#       <td id="T_cb73e_row2_col2" class="data row2 col2" >0.892027</td>
#       <td id="T_cb73e_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cb73e_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_cb73e_row3_col0" class="data row3 col0" >0.893740</td>
#       <td id="T_cb73e_row3_col1" class="data row3 col1" >0.899047</td>
#       <td id="T_cb73e_row3_col2" class="data row3 col2" >0.891792</td>
#       <td id="T_cb73e_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_cb73e_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_cb73e_row4_col0" class="data row4 col0" >0.901852</td>
#       <td id="T_cb73e_row4_col1" class="data row4 col1" >0.892027</td>
#       <td id="T_cb73e_row4_col2" class="data row4 col2" >0.892386</td>
#       <td id="T_cb73e_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>

# %%
sorted_idx = np.argsort(-model.feature_importances_)
feature_name = [tfidf_vect.get_feature_names()[i] for i in sorted_idx]
feature_imp = [round(x * 100, 1) for x in model.feature_importances_[sorted_idx]]

# %%
fi_dict = {
    'feature': feature_name,
    'importance': feature_imp
}
pd.DataFrame(fi_dict).to_excel('../../tmp/feature_imp.xlsx')

# %%
# == arquitetura lstm == 

def lstm():
    # limpar a sessão
    keras.backend.clear_session()
    # iniciar o modelo 
    model = keras.Sequential()
    # camada de entrada
    model.add(Input((150, )))
    # camada de word embedding
    model.add(Embedding(
        len(word_index) + 1, 
        300, 
        weights=[embedding_matrix], 
        trainable=True
    ))
    model.add(Convolution1D(
        128, 
        3, 
        activation="relu"
    ))
    model.add(GlobalMaxPool1D())
    # model.add(SpatialDropout1D(0.2))
    # camada LSTM
    model.add(Dropout(0.2))
    model.add(LSTM(128, return_sequences=True, activation='relu'))
    model.add(Dropout(0.2))
    model.add(LSTM(128))
    model.add(Dropout(0.2))
    # camadas de saída
    model.add(Dense(1, activation="sigmoid"))
    # compilar o modelo
    model.compile(optimizer=optimizers.Adam(), metrics='accuracy', loss='binary_crossentropy')
    model.summary()
    return model

print ("RNN-LSTM, Word Embeddings")
cr, cm = train_model(
    lstm(), 
    X_train_seq, 
    y_train, 
    X_valid_seq, 
    True
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# RNN-LSTM, Word Embeddings
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# <ipython-input-89-48551962afb0> in <module>
#      37 print ("RNN-LSTM, Word Embeddings")
#      38 cr, cm = train_model(
# ---> 39     lstm(),
#      40     X_train_seq,
#      41     y_train,
#
# <ipython-input-89-48551962afb0> in lstm()
#      24     # camada LSTM
#      25     model.add(Dropout(0.2))
# ---> 26     model.add(LSTM(128, return_sequences=True, activation='relu'))
#      27     model.add(Dropout(0.2))
#      28     model.add(LSTM(128))
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     203     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204     try:
# --> 205       result = method(self, *args, **kwargs)
#     206     finally:
#     207       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     231             if ndim != spec.ndim:
#     232                 raise ValueError(
# --> 233                     f'Input {input_index} of layer "{layer_name}" '
#     234                     "is incompatible with the layer: "
#     235                     f"expected ndim={spec.ndim}, found ndim={ndim}. "
#
# ValueError: Input 0 of layer "lstm" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 128)

# %%
# == arquitetura recurrent convolutional neural network (RCNN) == 

def rcnn():
    # limpar a sessão
    keras.backend.clear_session()
    # iniciar o modelo 
    model = keras.Sequential()
    # camada de entrada 
    model.add(Input((150, )))
    # camada de word embedding 
    model.add(Embedding(
        len(word_index) + 1, 
        300, 
        weights=[embedding_matrix], 
        trainable=True
    ))
    model.add(SpatialDropout1D(0.3))
    # camada recurrent 
    model.add(Bidirectional(
        GRU(
            50, 
            return_sequences=True
        )
    ))
    # camada convolucional
    model.add(Convolution1D(
        100, 
        3, 
        activation="relu"
    ))
    # camada pooling 
    model.add(GlobalMaxPool1D())
    # camada denso 
    model.add(Dense(
        50, 
        activation="relu"
    ))
    model.add(Dropout(0.25))
    model.add(Dense(
        1, 
        activation="sigmoid"
    ))
    # model compile
    model.compile(
        optimizer=optimizers.Adam(), 
        loss='binary_crossentropy'
    )
    model.summary()
    return model

print ("CNN, Word Embeddings")
cr, cm = train_model(
    rcnn(), 
    X_train_seq, 
    y_train, 
    X_valid_seq, 
    True
)
cm.style.background_gradient(
    cmap='viridis'
)
cr.style.background_gradient(
    cmap='viridis',
    subset=pd.IndexSlice[:, :'f1-score']
)
# Out:
# CNN, Word Embeddings
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 300)          24552600
#
#  spatial_dropout1d (SpatialD  (None, 150, 300)         0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 150, 100)         105600
#  l)
#
#  conv1d (Conv1D)             (None, 148, 100)          30100
#
#  global_max_pooling1d (Globa  (None, 100)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 50)                5050
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 24,693,401
# Trainable params: 24,693,401
# Non-trainable params: 0
# _________________________________________________________________
# 214/214 [==============================] - 63s 281ms/step - loss: 0.2167
# 38/38 [==============================] - 1s 19ms/step
# [[9.6686679e-01]
#  [9.9932629e-01]
#  [8.1339175e-01]
#  ...
#  [4.5689917e-04]
#  [2.7718401e-04]
#  [5.3993096e-03]]
# <style type="text/css">
# #T_83ba5_row0_col0, #T_83ba5_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_83ba5_row0_col1, #T_83ba5_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83ba5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >direita</th>
#       <th class="col_heading level0 col1" >esquerda</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83ba5_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_83ba5_row0_col0" class="data row0 col0" >587</td>
#       <td id="T_83ba5_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_83ba5_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_83ba5_row1_col0" class="data row1 col0" >103</td>
#       <td id="T_83ba5_row1_col1" class="data row1 col1" >514</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_19d39_row0_col0, #T_19d39_row0_col2, #T_19d39_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_19d39_row0_col1, #T_19d39_row1_col0, #T_19d39_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_19d39_row2_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_19d39_row2_col1, #T_19d39_row4_col1 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_19d39_row2_col2 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_19d39_row3_col0, #T_19d39_row3_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_19d39_row3_col2 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_19d39_row4_col0, #T_19d39_row4_col2 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19d39_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19d39_level0_row0" class="row_heading level0 row0" >direita</th>
#       <td id="T_19d39_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_19d39_row0_col1" class="data row0 col1" >0.850725</td>
#       <td id="T_19d39_row0_col2" class="data row0 col2" >0.919342</td>
#       <td id="T_19d39_row0_col3" class="data row0 col3" >690</td>
#     </tr>
#     <tr>
#       <th id="T_19d39_level0_row1" class="row_heading level0 row1" >esquerda</th>
#       <td id="T_19d39_row1_col0" class="data row1 col0" >0.833063</td>
#       <td id="T_19d39_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_19d39_row1_col2" class="data row1 col2" >0.908930</td>
#       <td id="T_19d39_row1_col3" class="data row1 col3" >514</td>
#     </tr>
#     <tr>
#       <th id="T_19d39_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_19d39_row2_col0" class="data row2 col0" >0.914452</td>
#       <td id="T_19d39_row2_col1" class="data row2 col1" >0.914452</td>
#       <td id="T_19d39_row2_col2" class="data row2 col2" >0.914452</td>
#       <td id="T_19d39_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_19d39_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_19d39_row3_col0" class="data row3 col0" >0.916532</td>
#       <td id="T_19d39_row3_col1" class="data row3 col1" >0.925362</td>
#       <td id="T_19d39_row3_col2" class="data row3 col2" >0.914136</td>
#       <td id="T_19d39_row3_col3" class="data row3 col3" >1204</td>
#     </tr>
#     <tr>
#       <th id="T_19d39_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_19d39_row4_col0" class="data row4 col0" >0.928733</td>
#       <td id="T_19d39_row4_col1" class="data row4 col1" >0.914452</td>
#       <td id="T_19d39_row4_col2" class="data row4 col2" >0.914897</td>
#       <td id="T_19d39_row4_col3" class="data row4 col3" >1204</td>
#     </tr>
#   </tbody>
# </table>
