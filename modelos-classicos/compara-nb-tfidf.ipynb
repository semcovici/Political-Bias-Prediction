# %% [markdown]
# # Importação das bibliotecas necessárias

# %%
import pandas as pd 

from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer
from datetime import datetime
from sklearn.feature_selection import SelectPercentile
from scipy.stats import uniform


from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
#from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score


from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn import set_config
set_config(display='diagram')
import datetime
import time

# %% [markdown]
# # Importação dos dados

# %%
data = pd.read_csv('../dataset/processed/artigos_de_partidos/artigos_partidos.csv')

# %%
# remocao de dados nulos
data = data[data['Conteudo'] != '']

# %%
# remocao de colunas desnecessarias
rem_cols = ['URL']
data.drop(rem_cols, axis=1, inplace=True)

# %%
data.head() # visualização das primeiras 5 linhas do dataframe
# Out:
#   Partido                                           Conteudo     Vies
# 0    Novo  Multa imposta ao candidato na condenação foi...  direita
# 1    Novo  Cadastro será usado como identificação junt...  direita
# 2    Novo  A Bancada do NOVO na Câmara considera temerá...  direita
# 3    Novo  Um ambiente com ausência de segurança juríd...  direita
# 4    Novo  Segundo o MP, o estado do RJ sequer utiliza os...  direita

# %%
# conversao dos rotulos categoricos para numericos
data['Vies'] = data['Vies'].map({'direita':2,
                                'centro': 1,
                                'esquerda': 0})

# %%
data.head()
# Out:
#   Partido                                           Conteudo  Vies
# 0    Novo  Multa imposta ao candidato na condenação foi...     2
# 1    Novo  Cadastro será usado como identificação junt...     2
# 2    Novo  A Bancada do NOVO na Câmara considera temerá...     2
# 3    Novo  Um ambiente com ausência de segurança juríd...     2
# 4    Novo  Segundo o MP, o estado do RJ sequer utiliza os...     2

# %% [markdown]
# # Splits que serão avaliados

# %%
# a seguir os dados serão divididos entre features (X) e label (y)

X_columns = [column for column in data.columns if column != 'Vies']
X = data[X_columns] # features
X.head()
# Out:
#   Partido                                           Conteudo
# 0    Novo  Multa imposta ao candidato na condenação foi...
# 1    Novo  Cadastro será usado como identificação junt...
# 2    Novo  A Bancada do NOVO na Câmara considera temerá...
# 3    Novo  Um ambiente com ausência de segurança juríd...
# 4    Novo  Segundo o MP, o estado do RJ sequer utiliza os...

# %%
y = data['Vies'] # label
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Vies, dtype: int64

# %% [markdown]
# ## Estratificação por viés

# %%
X_train_strat_vies, X_test_strat_vies, y_train_strat_vies, y_test_strat_vies = train_test_split(X, y.to_numpy(),
                                                                                                test_size=0.2,
                                                                                                random_state=42,
                                                                                                stratify=y)

X_train_strat_vies = X_train_strat_vies.drop('Partido', axis=1).Conteudo # remocao da coluna partido
X_test_strat_vies = X_test_strat_vies.drop('Partido', axis=1).Conteudo # remocao da coluna partido

# %%
X_train_strat_vies
# Out:
# 3285     Alagoas – O prefeito de Maceió, JHC (PL-AL), ...
# 5772     Após Indicação e Ofício apresentados pelo ...
# 2306     Brasília – “Você importa. Escolha a vida!”. ...
# 1757     Nota do PCB Santa Catarina sobre a conquista d...
# 690      O NOVO foi fundado em 2011 por pessoas comuns ...
#                                ...
# 3568     Amazonas – A deputada estadual Therezinha Ruiz...
# 4852     Brasília – O Ministério da Educação (MEC) ...
# 6461     O povo paraguaio está se insurgindo contra um...
# 10634    Na CCJ, governistas pedem vista e atrasam apre...
# 10822    PV Pernambuco repudia as ofertas do governo fe...
# Name: Conteudo, Length: 9370, dtype: object

# %% [markdown]
# ## Estratificação por partido

# %%
X_train_strat_part, X_test_strat_part, y_train_strat_part, y_test_strat_part = train_test_split(X, y.to_numpy(),
                                                                                                test_size=0.2,
                                                                                                random_state=42,
                                                                                                stratify=X['Partido'])

X_train_strat_part = X_train_strat_part.drop('Partido', axis=1).Conteudo # remocao da coluna partido
X_test_strat_part = X_test_strat_part.drop('Partido', axis=1).Conteudo # remocao da coluna partido

# %% [markdown]
# ## Teste com partidos fora do treino

# %%
direita = data[data['Vies'] == 2] # selecao apenas dos partidos de direita
centro = data[data['Vies'] == 1] # selecao apenas dos partidos de centro
esquerda = data[data['Vies'] == 0] # selecao apenas dos partidos de esquerda
total = data.shape[0] # quantidade total de linhas no dataset

# %%
print('Porcentagem dos partidos de direita em relação ao dataset:')
for part in direita['Partido'].unique():
    
    qnt_part = direita[direita['Partido'] == part].shape[0]
    porc = qnt_part / total * 100
    print(f'porcentagem do partido {part}: {porc:.2f}%')
# Out:
# Porcentagem dos partidos de direita em relação ao dataset:
# porcentagem do partido Novo: 10.22%
# porcentagem do partido PL: 28.90%
# porcentagem do partido PP: 5.01%
# porcentagem do partido União Brasil: 2.42%

# %%
print('Porcentagem dos partidos de centro em relação ao dataset:')
for part in centro['Partido'].unique():
    
    qnt_part = centro[centro['Partido'] == part].shape[0]
    porc = qnt_part / total * 100
    print(f'porcentagem do partido {part}: {porc:.2f}%')
# Out:
# Porcentagem dos partidos de centro em relação ao dataset:
# porcentagem do partido PDT: 3.82%
# porcentagem do partido MDB: 5.13%
# porcentagem do partido PSB: 15.04%
# porcentagem do partido PV: 7.41%

# %%
print('Porcentagem dos partidos de esquerda em relação ao dataset:')
for part in esquerda['Partido'].unique():
    
    qnt_part = esquerda[esquerda['Partido'] == part].shape[0]
    porc = qnt_part / total * 100
    print(f'porcentagem do partido {part}: {porc:.2f}%')
# Out:
# Porcentagem dos partidos de esquerda em relação ao dataset:
# porcentagem do partido PCB: 5.27%
# porcentagem do partido PSOL: 0.13%
# porcentagem do partido PSTU: 5.35%
# porcentagem do partido PCDoB: 5.14%
# porcentagem do partido PT: 5.10%
# porcentagem do partido Rede: 1.06%

# %% [markdown]
# Baseado nas porcentagens acima, o partido de esquerda, centro e direita que foram escolhidos para o conjunto de teste representam, respectivamente 5.53%, 7.35% e 10.34% do dataset. Dessa forma, o conjunto de teste será constituído por 5.53 + 7.35 + 10.34 = 23.22% do dataset original.

# %%
part_teste = ['PSTU', 'PV', 'Novo'] # partidos do conjunto de teste

test = data[data['Partido'].isin(part_teste)].copy() # selecao dos dados de teste
test.drop('Partido', axis=1, inplace=True) # remocao da coluna partido

train = data[~data['Partido'].isin(part_teste)].copy() # selecao dos dados de treino
train.drop('Partido', axis=1, inplace=True) # remocao da coluna partido

# %%
X_train_part_novos = train.drop('Vies', axis=1).Conteudo # X_train
y_train_part_novos = train['Vies'].to_numpy() # y_train

X_test_part_novos = test.drop('Vies', axis=1).Conteudo # X_test
y_test_part_novos = test['Vies'].to_numpy() # y_test

# %% [markdown]
# # Seleção do modelo

# %%
# Defina a função para calcular a porcentagem com base no número total de features
def percentage_features(percentage, total_features):
    return int(np.ceil(percentage * total_features / 100.0))

# %%
def seleciona_grid_tfidf(model, split):

    param_grid = None
    
    if split == 'strat_vies':
        X_train = X_train_strat_vies.copy()
        
    elif split == 'strat_partido':
        X_train = X_train_strat_part.copy()
        
    elif split == 'pred_partido_novo':
        X_train = X_train_part_novos.copy()
        

    if isinstance(model, MultinomialNB):
            param_grid = {
            "vect__ngram_range": [(1,2), (1,3), (1,4), (2,3), (2,4), (3,4)],
            "vect__analyzer": ['word','char'],
            "selection__percentile": [33, 66, 100],
            "estimator__alpha": [50, 15, 10, 5, 1, 0.5, 0.3, 0.1, 0.05, 0.03, 0.02, 0.01,  0.001],
            "estimator__fit_prior": [True, False],
            }

    if isinstance(model, SVC):
            param_grid = {
            "vect__ngram_range": [(1,2), (1,3), (1,4), (2,3), (2,4), (3,4)],
            "vect__analyzer": ['word','char'],
            "selection__k": [200,400,600,800,1024],
            "estimator__gamma": [1, 0.1, 0.01, 0.001],
            "estimator__kernel": ['linear', 'sigmoid'],
            "estimator__C": [0.1, 1, 10, 100]
            }
            
    if isinstance(model, LinearSVC):
        
            param_grid = {
            "vect__ngram_range": [(1,2), (1,3), (1,4), (2,3), (2,4), (3,4)],
            "vect__analyzer": ['word','char'],
            "selection__percentile": [33, 66, 100],
            "estimator__dual": [True, False],
            "estimator__penalty": ['l1', 'l2'],
            "estimator__fit_intercept": [True, False],
            "estimator__C": uniform(loc=0, scale=4)
            }


    if isinstance(model, RandomForestClassifier):
        param_grid = {
        "vect__ngram_range": [(1,2), (1,3), (1,4), (2,3), (2,4), (3,4)],
        "vect__analyzer": ['word','char'],
        "selection__k": [200,400,600,800,1024],
        "estimator__n_estimators": np.arange(20,150), 
        "estimator__max_features": ['log2', 'sqrt'],
        "estimator__max_depth": np.arange(10,110),
        "estimator__min_samples_split": np.arange(2,11),
        "estimator__min_samples_leaf": np.arange(1,5),
        "estimator__bootstrap": [True, False]
        }
        
    if isinstance(model, XGBClassifier):
        param_grid = {
        "vect__ngram_range": [(1,2), (1,3), (1,4), (2,3), (2,4), (3,4)],
        "vect__analyzer": ['word','char'],
        "selection__percentile": [33, 66, 100],
        "estimator__gamma": np.linspace(0,9,100, dtype=np.int64),
        "estimator__alpha": np.linspace(0,40,100, dtype=np.int64),
        "estimator__lambda": np.linspace(0,3,10, dtype=np.int64),
        "estimator__colsample_bytree": np.linspace(0.2,1,10, dtype=np.int64)
        }

    return param_grid

# %%
def fit_e_avalia(split, random_search):
    
    inicio_random_search = datetime.datetime.now()
    
    if split == 'strat_vies': # estratificacao pela label
        model_trained = random_search.fit(X_train_strat_vies, y_train_strat_vies) # fit

        fim_random_search = datetime.datetime.now()
        tempo_total = fim_random_search - inicio_random_search
        print(f'Duração da Random Search: {tempo_total}')

        y_pred = model_trained.predict(X_test_strat_vies) # predicao
        f1 = f1_score(y_test_strat_vies, y_pred, average= 'macro') # f1
        report = classification_report(y_test_strat_vies, y_pred, output_dict=True) # class report

    elif split == 'strat_partido': # estratificacao pelos partidos 
        model_trained = random_search.fit(X_train_strat_part, y_train_strat_part) # fit

        fim_random_search = datetime.datetime.now()
        tempo_total = fim_random_search - inicio_random_search
        print(f'Duração da Random Search: {tempo_total}')

        y_pred = model_trained.predict(X_test_strat_part) # predicao
        f1 = f1_score(y_test_strat_part, y_pred, average= 'macro') # f1
        report = classification_report(y_test_strat_part, y_pred, output_dict=True) # class report

    elif split == 'pred_partido_novo': # predicao de partidos nao vistos no teste
        model_trained = random_search.fit(X_train_part_novos, y_train_part_novos) # fit

        fim_random_search = datetime.datetime.now()
        tempo_total = fim_random_search - inicio_random_search
        print(f'Duração da Random Search: {tempo_total}')

        y_pred = model_trained.predict(X_test_part_novos) # predicao
        f1 = f1_score(y_test_part_novos, y_pred, average= 'macro') # f1
        report = classification_report(y_test_part_novos, y_pred, output_dict=True) # class report
    
    return model_trained, tempo_total, f1, report

# %%
def compara_tfidf(iteracoes, modelos, nome_arquivo):

    # seletor de features
    selection = SelectPercentile()

    # possibilidades de oversampling ou nao
    samplers = [RandomOverSampler(random_state=42), None]

    # diferentes splits que serao avaliador
    splits = ['strat_vies', 'strat_partido', 'pred_partido_novo'] 
    
    # vetorizador do texto
    vectorizer = TfidfVectorizer()

    # dataframe em que sera inserido os dados do modelo testado 
    df_resultados = pd.DataFrame(columns=['modelo', 'split', 'sampler', 'scaling',
                                          'duracao_random_search','qnt_iteracoes',
                                          'f1_randsearch',
                                          'melhores_parametros', 'f1_pred',
                                          'class_report'])
    
    for model in modelos:

        for sampler in samplers:

            for split in splits:
                
                # seleciona grid de parametros
                param_grid = seleciona_grid_tfidf(model, split)
                
                # seleciona scaler
                if isinstance(model, MultinomialNB):
                    scaler = MaxAbsScaler() # normaliza e garante valores nao negativos
                else:
                    scaler = MaxAbsScaler()
        
                # define o pipeline
                pipeline = Pipeline([
                        ('vect', vectorizer), 
                        ('scaling', scaler), 
                        ('selection', selection),
                        ('ros', sampler),
                        ('estimator', model)
                        ])
        
                
                #  --- Prints das configurações dessa iteracao ---
                print(f'Modelo: {model}')
                print(f'Split: {split}')
                print(f'Scaler: {scaler}')
                print(f'Sampler: {sampler}')
                    
        
                # definicao da randomized search
                random_search = RandomizedSearchCV(pipeline, param_distributions=param_grid,cv=StratifiedKFold(n_splits=5),
                                                    n_iter=iteracoes, n_jobs=1, random_state=42, scoring='f1_macro')


                # fit e avaliacao pela randomized search
                model_trained, tempo_total, f1, report = fit_e_avalia(split, random_search)
                
                print('---')
                resultados = model_trained.cv_results_

                for params, score in zip(resultados['params'], resultados['mean_test_score']):
                    print(f"Parâmetros: {params}, Score: {score}")
                print('---')
                    
                # melhor metrica na random search
                score_random_search = model_trained.best_score_
                score_random_search *= 100
                score_random_search = round(score_random_search,2)
                print(f'Melhor F1 na Random Search: {score_random_search}%')
                
                # melhores parametros encontrados
                print('Melhores parâmetros encontrados:')
                print(model_trained.best_params_)

                
                # acuracia da predicao
                f1 *= 100
                f1 = round(f1,2)
                print(f'F1 macro = {f1}%')
        
                # classification report
                print(report)
                        
                
                print('----------------------------------------------')
                
                # --- Escrita em memória secundária ---

                # Nova linha que sera adicionada
                nova_linha = {'modelo': model, 'split': split,
                              'sampler': str(sampler), 'scaling': scaler,
                              'duracao_random_search': tempo_total,
                              'qnt_iteracoes': iteracoes,
                              'f1_randsearch': f'{score_random_search}%',
                              'melhores_parametros': str(model_trained.best_params_),
                              'f1_pred': f'{f1}%', 'class_report': report}
            
                # Cria um novo DataFrame com a nova linha
                nova_linha_resultados = pd.DataFrame([nova_linha])
            
                # Concatena o novo DataFrame com o DataFrame existente
                df_resultados = pd.concat([df_resultados, nova_linha_resultados], ignore_index=True)
    
    
    print('Fim dos testes')
    
    # salvamento do dataframe de resultados apos os testes terem terminado
    df_resultados.to_csv(nome_arquivo, index=False)

# %%
modelos = [MultinomialNB()]

compara_tfidf(40, modelos, 'compara-nb-tfidf.csv')
# Out:
# Modelo: MultinomialNB()
# Split: strat_vies
# Scaler: MaxAbsScaler()
# Sampler: RandomOverSampler(random_state=42)
# Duração da Random Search: 2:39:36.475990
# ---
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.802065947236831
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.8694765041714831
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.9443496096044679
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8739083836592583
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9275339457523415
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.8852328511736598
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8971764360502286
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.9141867142666058
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.9381280270014198
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 1}, Score: 0.8853641690098819
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.9191358556133409
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7596902521157258
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.8586075536634254
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9274069618441487
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.3}, Score: 0.8770172226238463
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.02}, Score: 0.9334331071173889
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9193901343396444
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.001}, Score: 0.8283039127019031
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.9402844394108231
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.9333640288650781
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.821907325073977
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.735066732892223
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.001}, Score: 0.8850026845900771
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 50}, Score: 0.6949269668431977
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.8716404202013335
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.9294558904972815
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8773759731499592
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9465161387993177
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.928845795248944
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.925811678471246
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.1}, Score: 0.8825238050399913
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.7454235302528045
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.8915773854096741
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.9433864197411801
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9014393750267201
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9364706058400485
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.9311010336493061
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9333640288650781
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8121767925115335
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 15}, Score: 0.8927092687115813
# ---
# Melhor F1 na Random Search: 94.65%
# Melhores parâmetros encontrados:
# {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}
# F1 macro = 95.58%
# {'0': {'precision': 0.9314285714285714, 'recall': 0.9476744186046512, 'f1-score': 0.9394812680115274, 'support': 516}, '1': {'precision': 0.9581005586592178, 'recall': 0.9320652173913043, 'f1-score': 0.9449035812672175, 'support': 736}, '2': {'precision': 0.9782214156079855, 'recall': 0.9880843263061412, 'f1-score': 0.9831281349749201, 'support': 1091}, 'accuracy': 0.9615877080665813, 'macro avg': {'precision': 0.9559168485652583, 'recall': 0.9559413207673656, 'f1-score': 0.9558376614178883, 'support': 2343}, 'weighted avg': {'precision': 0.9615956971654457, 'recall': 0.9615877080665813, 'f1-score': 0.9615083932412539, 'support': 2343}}
# ----------------------------------------------
# Modelo: MultinomialNB()
# Split: strat_partido
# Scaler: MaxAbsScaler()
# Sampler: RandomOverSampler(random_state=42)
# Duração da Random Search: 2:24:46.185001
# ---
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.804549873481891
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.8738057807131033
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.942653944674694
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8736150546548505
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9275543253364169
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.890177547092794
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8973724135084412
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.9147309851770556
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.937470869987909
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 1}, Score: 0.8886975355123902
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.9171574419369483
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7636214233041624
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.8590377422201998
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9295143925268853
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.3}, Score: 0.8780363687683913
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.02}, Score: 0.9332950104155422
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9205412759257007
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.001}, Score: 0.8351175563787049
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.9402416794481679
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.9306728666977927
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8223863982646771
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.7421305901896382
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.001}, Score: 0.8847139671291334
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 50}, Score: 0.694642276540953
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.8720819055069351
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.9292813942720131
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8790701626285238
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9465985975257798
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.927932863492072
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9260261795424876
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.1}, Score: 0.8837673264918469
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.7438151670815526
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.8972704886783083
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.9422707403862185
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9017979867708277
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9353068686670992
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.9320863924474031
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9306728666977927
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8144949067077757
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 15}, Score: 0.8965474337652924
# ---
# Melhor F1 na Random Search: 94.66%
# Melhores parâmetros encontrados:
# {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}
# F1 macro = 94.49%
# {'0': {'precision': 0.9241245136186771, 'recall': 0.9205426356589147, 'f1-score': 0.9223300970873787, 'support': 516}, '1': {'precision': 0.9352617079889807, 'recall': 0.9225543478260869, 'f1-score': 0.9288645690834473, 'support': 736}, '2': {'precision': 0.9782411604714415, 'recall': 0.9890009165902841, 'f1-score': 0.98359161349134, 'support': 1091}, 'accuracy': 0.9530516431924883, 'macro avg': {'precision': 0.9458757940263665, 'recall': 0.9440326333584285, 'f1-score': 0.9449287598873887, 'support': 2343}, 'weighted avg': {'precision': 0.9528220111743362, 'recall': 0.9530516431924883, 'f1-score': 0.9529087081782144, 'support': 2343}}
# ----------------------------------------------
# Modelo: MultinomialNB()
# Split: pred_partido_novo
# Scaler: MaxAbsScaler()
# Sampler: RandomOverSampler(random_state=42)
# Duração da Random Search: 1:55:47.251738
# ---
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.7182809672079044
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.7333048741755415
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.8544832782121233
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.7533963849287295
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8339879327020704
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.8180526817472344
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.7903328611293506
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.832048736710016
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.8435522334964091
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 1}, Score: 0.7615859101946008
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.8167053910467805
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7141416201637953
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7222394370163994
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8169694138142581
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.3}, Score: 0.7527938695495162
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.02}, Score: 0.8409674377648818
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8126850158809799
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.001}, Score: 0.744261844170198
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.8487679626199292
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.8487707242750586
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.7370101570011915
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.7171342845287045
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.001}, Score: 0.7830321554568631
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 50}, Score: 0.681304097101169
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.7383072916574742
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.8401727469352384
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.7649615342829553
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8536955309081286
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.8470149695058261
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.8359142750995948
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.1}, Score: 0.766040466894806
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.7038311126460481
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.809107788059458
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.8500743049337842
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.771064169462646
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.843136977313143
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8430506500282717
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.8487707242750586
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.7303587067832354
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 15}, Score: 0.8176057049920515
# ---
# Melhor F1 na Random Search: 85.45%
# Melhores parâmetros encontrados:
# {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}
# F1 macro = 90.33%
# {'0': {'precision': 0.8252730109204368, 'recall': 0.8437001594896332, 'f1-score': 0.8343848580441641, 'support': 627}, '1': {'precision': 0.9747474747474747, 'recall': 0.8894009216589862, 'f1-score': 0.9301204819277109, 'support': 868}, '2': {'precision': 0.9221604447974583, 'recall': 0.9699248120300752, 'f1-score': 0.9454397394136808, 'support': 1197}, 'accuracy': 0.9145616641901931, 'macro avg': {'precision': 0.9073936434884566, 'recall': 0.901008631059565, 'f1-score': 0.9033150264618519, 'support': 2692}, 'weighted avg': {'precision': 0.916550162834502, 'recall': 0.9145616641901931, 'f1-score': 0.914634194793878, 'support': 2692}}
# ----------------------------------------------
# Modelo: MultinomialNB()
# Split: strat_vies
# Scaler: MaxAbsScaler()
# Sampler: None
# Duração da Random Search: 2:21:58.379407
# ---
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.7699482930612171
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.4920913917023884
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.9413517566142147
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.87392739965786
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9278242496722842
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.8535844429278227
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8970975498275745
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.8822126354352008
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.9379462467468613
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 1}, Score: 0.883871411828969
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.9167823517748215
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7092875977925983
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7148643660532156
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9389414915109683
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.3}, Score: 0.8757223726358829
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.02}, Score: 0.9347875599691646
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9248566815627971
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.001}, Score: 0.826410038348848
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.9412122514613154
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.9217856997758602
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8203046240556604
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.7325977518775516
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.001}, Score: 0.8845509119975075
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 50}, Score: 0.5166096099213073
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.8480971771998773
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.9288639006065855
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8779342713921195
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9484124458675527
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.9158503615481915
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.8997499272530188
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.1}, Score: 0.8838661927271823
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.42130022630107355
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.8663286004596706
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.9475970503853226
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.8605739733721627
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.936711792709002
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.9310135188321708
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9220034054711139
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8138256259716042
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 15}, Score: 0.850592298998951
# ---
# Melhor F1 na Random Search: 94.84%
# Melhores parâmetros encontrados:
# {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}
# F1 macro = 95.54%
# {'0': {'precision': 0.9099264705882353, 'recall': 0.9593023255813954, 'f1-score': 0.9339622641509433, 'support': 516}, '1': {'precision': 0.9633802816901409, 'recall': 0.9293478260869565, 'f1-score': 0.9460580912863071, 'support': 736}, '2': {'precision': 0.9871441689623508, 'recall': 0.9853345554537122, 'f1-score': 0.9862385321100918, 'support': 1091}, 'accuracy': 0.9620145113102859, 'macro avg': {'precision': 0.9534836404135757, 'recall': 0.9579949023740214, 'f1-score': 0.9554196291824474, 'support': 2343}, 'weighted avg': {'precision': 0.9626735955976943, 'recall': 0.9620145113102859, 'f1-score': 0.9621039359883565, 'support': 2343}}
# ----------------------------------------------
# Modelo: MultinomialNB()
# Split: strat_partido
# Scaler: MaxAbsScaler()
# Sampler: None
# Duração da Random Search: 2:13:53.842271
# ---
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.7732134312440414
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.5185107830061162
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.9386243937974361
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.874624268604987
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9272060303352692
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.8561978084422959
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8988518647224286
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.8849235053908734
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.936398673889394
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 1}, Score: 0.8869977743516303
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.917951318819305
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7153013106470629
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.7201546972465779
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9371212761292582
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.3}, Score: 0.8764701179230092
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.02}, Score: 0.9338119757922232
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.9249942373319344
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.001}, Score: 0.8347126813681689
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.9402794630065868
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.923784632490252
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8240823139143902
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.7391817975297388
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.001}, Score: 0.8849927862610384
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 50}, Score: 0.5212566710123726
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.8526615111979678
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.928282837426641
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8792428796200454
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9453813915422691
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.9179375599893232
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9036487726867767
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.1}, Score: 0.8863835339039674
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.4249075713246736
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.87038316350471
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.9444361496284823
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.8632572551089698
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.9360668150340331
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.9311719574776134
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.9243242513016966
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8187123222528022
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 15}, Score: 0.8537404616182698
# ---
# Melhor F1 na Random Search: 94.54%
# Melhores parâmetros encontrados:
# {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}
# F1 macro = 94.34%
# {'0': {'precision': 0.8996282527881041, 'recall': 0.937984496124031, 'f1-score': 0.9184060721062619, 'support': 516}, '1': {'precision': 0.9400278940027894, 'recall': 0.9157608695652174, 'f1-score': 0.9277357192016518, 'support': 736}, '2': {'precision': 0.9852941176470589, 'recall': 0.9825847846012832, 'f1-score': 0.9839375860486462, 'support': 1091}, 'accuracy': 0.9517712334613743, 'macro avg': {'precision': 0.941650088145984, 'recall': 0.9454433834301771, 'f1-score': 0.9433597924521866, 'support': 2343}, 'weighted avg': {'precision': 0.9522085321287478, 'recall': 0.9517712334613743, 'f1-score': 0.9518510153300553, 'support': 2343}}
# ----------------------------------------------
# Modelo: MultinomialNB()
# Split: pred_partido_novo
# Scaler: MaxAbsScaler()
# Sampler: None
# Duração da Random Search: 2:05:22.915537
# ---
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.7159610239140519
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.43044147702405483
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.843630250634256
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.754342519789868
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8361618117175815
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.7129971248721485
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.7939220724983871
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 15}, Score: 0.7422254793088104
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.8529256797334762
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 1}, Score: 0.7660879348020228
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.1}, Score: 0.8238799117065774
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.6949946139874812
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.6912828538388895
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8425615234108743
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.3}, Score: 0.751952924727546
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.02}, Score: 0.8423074514646448
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.3}, Score: 0.8329181886571604
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.001}, Score: 0.7448708386527347
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.8540570044630151
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 5}, Score: 0.8133282015028442
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'char', 'selection__percentile': 66, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.7355760393932446
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.01}, Score: 0.7176671411809558
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.001}, Score: 0.7847689496422274
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 50}, Score: 0.4545849048715057
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 1}, Score: 0.7252112060812881
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.8394972538430021
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.767383474774901
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.85844307572491
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 10}, Score: 0.8031584839367302
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.7686670857614681
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.1}, Score: 0.7683831269858451
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.33732816015730194
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 50}, Score: 0.7399584727936336
# Parâmetros: {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}, Score: 0.8592365929218969
# Parâmetros: {'vect__ngram_range': (1, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.7285486973568935
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.8483717642132754
# Parâmetros: {'vect__ngram_range': (2, 3), 'vect__analyzer': 'word', 'selection__percentile': 33, 'estimator__fit_prior': True, 'estimator__alpha': 0.03}, Score: 0.8447698903792334
# Parâmetros: {'vect__ngram_range': (2, 4), 'vect__analyzer': 'word', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 5}, Score: 0.8136838157713623
# Parâmetros: {'vect__ngram_range': (1, 3), 'vect__analyzer': 'char', 'selection__percentile': 100, 'estimator__fit_prior': False, 'estimator__alpha': 0.03}, Score: 0.7312063181993197
# Parâmetros: {'vect__ngram_range': (1, 2), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 15}, Score: 0.7113946366913119
# ---
# Melhor F1 na Random Search: 85.92%
# Melhores parâmetros encontrados:
# {'vect__ngram_range': (3, 4), 'vect__analyzer': 'word', 'selection__percentile': 66, 'estimator__fit_prior': False, 'estimator__alpha': 0.02}
# F1 macro = 86.33%
# {'0': {'precision': 0.8075601374570447, 'recall': 0.7496012759170654, 'f1-score': 0.7775020678246486, 'support': 627}, '1': {'precision': 0.9742547425474255, 'recall': 0.8283410138248848, 'f1-score': 0.8953922789539228, 'support': 868}, '2': {'precision': 0.858600583090379, 'recall': 0.9841269841269841, 'f1-score': 0.9170883612300506, 'support': 1197}, 'accuracy': 0.8792719167904903, 'macro avg': {'precision': 0.8801384876982831, 'recall': 0.8540230912896448, 'f1-score': 0.8633275693362074, 'support': 2692}, 'weighted avg': {'precision': 0.8840037966849613, 'recall': 0.8792719167904903, 'f1-score': 0.8775813755759401, 'support': 2692}}
# ----------------------------------------------
# Fim dos testes
